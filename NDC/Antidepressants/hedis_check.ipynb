# %%
import pandas as pd
base_url = "https://rxnav.nlm.nih.gov/REST/rxcui/"
base_url_2 = "https://rxnav.nlm.nih.gov/REST/"

# %%
df = pd.read_excel("Absent_antidepressant.xlsx",dtype="object")

# %%
df
# Out:
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7254  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7255  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7256  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7257  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7258  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7254              2021-03-31      2200177
# 7255              2021-03-31      2200178
# 7256              2021-03-31      2200180
# 7257              2021-03-31      2200181
# 7258              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7254  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7255  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7256  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7257  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7258  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7254  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7255                                                NaN  oral          NaN
# 7256  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7257                                                NaN  oral          NaN
# 7258  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7254  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7255  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7256  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7257  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7258  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7259 rows x 13 columns]

# %%
#find the status of the not found drugs
df_status = pd.DataFrame()
index = 0
for code in df['Code']:
    getndcStatus = 'ndcstatus.json?ndc={}&history=0&altpkg=1'.format(code)
    df_type = pd.read_json(base_url_2+getndcStatus)
    df_type = df_type.transpose()
    df_type['ndc'] = code
    df_status = pd.concat([df_status, df_type]).drop_duplicates(subset=['ndc']).reset_index(drop=True)
df_status
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO      N    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1       YES      N    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES      N    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 3        NO      N    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 4       YES      N    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 7254                  None
# 7255                  None
# 7256                  None
# 7257                  None
# 7258                  None
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1           ACTIVE  00002323101
# 2           ACTIVE  00002323133
# 3         OBSOLETE  00002323230
# 4           ACTIVE  00002323301
# ...            ...          ...
# 7254
# 7255
# 7256
# 7257
# 7258
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 3     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 7254                                                NaN
# 7255                                                NaN
# 7256                                                NaN
# 7257                                                NaN
# 7258                                                NaN
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...    ACTIVE  00002323101
# 2     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...    ACTIVE  00002323133
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 4     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...    ACTIVE  00002323301
# ...                                                 ...       ...          ...
# 7254                                                 {}   UNKNOWN      2200177
# 7255                                                 {}   UNKNOWN      2200178
# 7256                                                 {}   UNKNOWN      2200180
# 7257                                                 {}   UNKNOWN      2200181
# 7258                                                 {}   UNKNOWN      2200183
#
# [7259 rows x 12 columns]

# %%
df_status.to_excel("ndcstatus.xlsx",index=False)

# %%
df_obsolete = df_status.loc[df_status['active']== 'NO'].reset_index(drop=True)

# %%
df_obsolete
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO      N    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1        NO      N    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 2        NO      N    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 3        NO      N    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 4        NO      N    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# ...     ...    ...     ...                                                ...
# 4286     NO      N    None                      fluoxetine 20 MG Oral Capsule
# 4287     NO      N    None                       citalopram 10 MG Oral Tablet
# 4288     NO      N    None                       citalopram 20 MG Oral Tablet
# 4289     NO      N    None                       citalopram 40 MG Oral Tablet
# 4290     NO      N    None  24 HR bupropion hydrochloride 150 MG Extended ...
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1         OBSOLETE  00002323230
# 2           ACTIVE  00002324001
# 3           ACTIVE  00002324007
# 4           ACTIVE  00002324033
# ...            ...          ...
# 4286        ACTIVE  75921064830
# 4287        ACTIVE  76282020601
# 4288        ACTIVE  76282020701
# 4289        ACTIVE  76282020801
# 4290        ACTIVE  76519102105
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 2     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 3     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 4     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# ...                                                 ...     ...       ...
# 4286  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 4287  [{'activeRxcui': '283672', 'originalRxcui': '2...  283672       YES
# 4288  [{'activeRxcui': '200371', 'originalRxcui': '2...  200371       YES
# 4289  [{'activeRxcui': '309314', 'originalRxcui': '3...  309314       YES
# 4290  [{'activeRxcui': '993541', 'originalRxcui': '9...  993541       YES
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  OBSOLETE  00002324001
# 3        {'sourceName': ['MTHFDA', 'MTHSPL', 'RXNORM']}  OBSOLETE  00002324007
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002324033
# ...                                                 ...       ...          ...
# 4286               {'sourceName': ['MTHSPL', 'RXNORM']}  OBSOLETE  75921064830
# 4287  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  OBSOLETE  76282020601
# 4288  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  OBSOLETE  76282020701
# 4289  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  OBSOLETE  76282020801
# 4290               {'sourceName': ['MTHSPL', 'RXNORM']}  OBSOLETE  76519102105
#
# [4291 rows x 12 columns]

# %%
df_active = df_status.loc[df_status['active']== 'YES'].reset_index(drop=True)

# %%
df_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0       YES      N    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 1       YES      N    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES      N    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 3       YES      N    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 4       YES      N    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 2647    YES      N    None                      fluoxetine 10 MG Oral Capsule
# 2648    YES      N    None                      fluoxetine 20 MG Oral Capsule
# 2649    YES      N    None                      fluoxetine 20 MG Oral Capsule
# 2650    YES      N    None                      fluoxetine 20 MG Oral Capsule
# 2651    YES      N    None  24 HR bupropion hydrochloride 150 MG Extended ...
#
#      conceptStatus        ndc11  \
# 0           ACTIVE  00002323101
# 1           ACTIVE  00002323133
# 2           ACTIVE  00002323301
# 3           ACTIVE  00002323330
# 4           ACTIVE  00002323333
# ...            ...          ...
# 2647        ACTIVE  76365010106
# 2648        ACTIVE  76365010202
# 2649        ACTIVE  76365010204
# 2650        ACTIVE  76365010206
# 2651        ACTIVE  76519102103
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 3     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 2647  [{'activeRxcui': '310384', 'originalRxcui': '3...  310384       YES
# 2648  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2649  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2650  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2651  [{'activeRxcui': '993541', 'originalRxcui': '9...  993541       YES
#
#                                              sourceList  status          ndc
# 0     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...  ACTIVE  00002323101
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323133
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  ACTIVE  00002323301
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323330
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323333
# ...                                                 ...     ...          ...
# 2647        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010106
# 2648        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010202
# 2649        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010204
# 2650        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010206
# 2651        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519102103
#
# [2652 rows x 12 columns]

# %%
df_not_active = df_status.loc[df_status['active']!= 'YES'].reset_index(drop=True)

# %%
df_not_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO      N    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1        NO      N    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 2        NO      N    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 3        NO      N    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 4        NO      N    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# ...     ...    ...     ...                                                ...
# 4602                  None
# 4603                  None
# 4604                  None
# 4605                  None
# 4606                  None
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1         OBSOLETE  00002323230
# 2           ACTIVE  00002324001
# 3           ACTIVE  00002324007
# 4           ACTIVE  00002324033
# ...            ...          ...
# 4602
# 4603
# 4604
# 4605
# 4606
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 2     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 3     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 4     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# ...                                                 ...     ...       ...
# 4602                                                NaN
# 4603                                                NaN
# 4604                                                NaN
# 4605                                                NaN
# 4606                                                NaN
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  OBSOLETE  00002324001
# 3        {'sourceName': ['MTHFDA', 'MTHSPL', 'RXNORM']}  OBSOLETE  00002324007
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002324033
# ...                                                 ...       ...          ...
# 4602                                                 {}   UNKNOWN      2200177
# 4603                                                 {}   UNKNOWN      2200178
# 4604                                                 {}   UNKNOWN      2200180
# 4605                                                 {}   UNKNOWN      2200181
# 4606                                                 {}   UNKNOWN      2200183
#
# [4607 rows x 12 columns]

# %%
df_active.to_excel("active.xlsx",index=False)
df_not_active.to_excel("NOT_active.xlsx",index=False)

# %%
df_not_active_blank = df_not_active.loc[df_not_active['active']!= 'NO'].reset_index(drop=True)

# %%
df_not_active_blank
# Out:
#     active altNdc comment conceptName conceptStatus ndc11 ndcHistory rxcui  \
# 0                    None                                        NaN
# 1                    None                                        NaN
# 2                    None                                        NaN
# 3                    None                                        NaN
# 4                    None                                        NaN
# ..     ...    ...     ...         ...           ...   ...        ...   ...
# 311                  None                                        NaN
# 312                  None                                        NaN
# 313                  None                                        NaN
# 314                  None                                        NaN
# 315                  None                                        NaN
#
#     rxnormNdc sourceList   status      ndc
# 0                     {}  UNKNOWN   104836
# 1                     {}  UNKNOWN   104837
# 2                     {}  UNKNOWN   104838
# 3                     {}  UNKNOWN   104849
# 4                     {}  UNKNOWN   106834
# ..        ...        ...      ...      ...
# 311                   {}  UNKNOWN  2200177
# 312                   {}  UNKNOWN  2200178
# 313                   {}  UNKNOWN  2200180
# 314                   {}  UNKNOWN  2200181
# 315                   {}  UNKNOWN  2200183
#
# [316 rows x 12 columns]
