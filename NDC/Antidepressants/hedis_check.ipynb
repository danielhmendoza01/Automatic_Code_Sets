# %%
import pandas as pd
base_url = "https://rxnav.nlm.nih.gov/REST/rxcui/"
base_url_2 = "https://rxnav.nlm.nih.gov/REST/"

# %%
df = pd.read_excel("Absent_Antidepressants.xlsx",dtype="object")

# %%
df
# Out:
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7283  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7284  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7285  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7286  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7287  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7283              2021-03-31      2200177
# 7284              2021-03-31      2200178
# 7285              2021-03-31      2200180
# 7286              2021-03-31      2200181
# 7287              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7283  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7284  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7285  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7286  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7287  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7283  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7284                                                NaN  oral          NaN
# 7285  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7286                                                NaN  oral          NaN
# 7287  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7283  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7284  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7285  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7286  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7287  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7288 rows x 13 columns]

# %%
#find the status of the not found drugs
df_status = pd.DataFrame()
index = 0
for code in df['Code']:
    getndcStatus = 'ndcstatus.json?ndc={}&history=0&altpkg=1'.format(code)
    df_type = pd.read_json(base_url_2+getndcStatus)
    df_type = df_type.transpose()
    df_type['ndc'] = code
    df_status = pd.concat([df_status, df_type]).drop_duplicates(subset=['ndc']).reset_index(drop=True)
df_status
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO      N    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1       YES      N    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES      N    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 3        NO      N    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 4       YES      N    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 7283                  None
# 7284                  None
# 7285                  None
# 7286                  None
# 7287                  None
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1           ACTIVE  00002323101
# 2           ACTIVE  00002323133
# 3         OBSOLETE  00002323230
# 4           ACTIVE  00002323301
# ...            ...          ...
# 7283
# 7284
# 7285
# 7286
# 7287
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 3     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 7283                                                NaN
# 7284                                                NaN
# 7285                                                NaN
# 7286                                                NaN
# 7287                                                NaN
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...    ACTIVE  00002323101
# 2     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...    ACTIVE  00002323133
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 4     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...    ACTIVE  00002323301
# ...                                                 ...       ...          ...
# 7283                                                 {}   UNKNOWN      2200177
# 7284                                                 {}   UNKNOWN      2200178
# 7285                                                 {}   UNKNOWN      2200180
# 7286                                                 {}   UNKNOWN      2200181
# 7287                                                 {}   UNKNOWN      2200183
#
# [7288 rows x 12 columns]

# %%
df_status.to_excel("ndcstatus.xlsx",index=False)

# %%
df_status.altNdc.replace("N", "NO", inplace=True)
df_status.altNdc.replace("Y", "YES", inplace=True)

# %%
df_status
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO     NO    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1       YES     NO    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES     NO    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 3        NO     NO    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 4       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 7283                  None
# 7284                  None
# 7285                  None
# 7286                  None
# 7287                  None
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1           ACTIVE  00002323101
# 2           ACTIVE  00002323133
# 3         OBSOLETE  00002323230
# 4           ACTIVE  00002323301
# ...            ...          ...
# 7283
# 7284
# 7285
# 7286
# 7287
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 3     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 7283                                                NaN
# 7284                                                NaN
# 7285                                                NaN
# 7286                                                NaN
# 7287                                                NaN
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...    ACTIVE  00002323101
# 2     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...    ACTIVE  00002323133
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 4     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...    ACTIVE  00002323301
# ...                                                 ...       ...          ...
# 7283                                                 {}   UNKNOWN      2200177
# 7284                                                 {}   UNKNOWN      2200178
# 7285                                                 {}   UNKNOWN      2200180
# 7286                                                 {}   UNKNOWN      2200181
# 7287                                                 {}   UNKNOWN      2200183
#
# [7288 rows x 12 columns]

# %%
df_obsolete = df_status.loc[df_status['active']== 'NO'].reset_index(drop=True)

# %%
df_obsolete
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO     NO    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1        NO     NO    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 2        NO     NO    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 3        NO     NO    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 4        NO     NO    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# ...     ...    ...     ...                                                ...
# 4345     NO     NO    None                      fluoxetine 20 MG Oral Capsule
# 4346     NO     NO    None                       citalopram 10 MG Oral Tablet
# 4347     NO     NO    None                       citalopram 20 MG Oral Tablet
# 4348     NO     NO    None                       citalopram 40 MG Oral Tablet
# 4349     NO     NO    None  24 HR bupropion hydrochloride 150 MG Extended ...
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1         OBSOLETE  00002323230
# 2           ACTIVE  00002324001
# 3           ACTIVE  00002324007
# 4           ACTIVE  00002324033
# ...            ...          ...
# 4345        ACTIVE  75921064830
# 4346        ACTIVE  76282020601
# 4347        ACTIVE  76282020701
# 4348        ACTIVE  76282020801
# 4349        ACTIVE  76519102105
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 2     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 3     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 4     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# ...                                                 ...     ...       ...
# 4345  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 4346  [{'activeRxcui': '283672', 'originalRxcui': '2...  283672       YES
# 4347  [{'activeRxcui': '200371', 'originalRxcui': '2...  200371       YES
# 4348  [{'activeRxcui': '309314', 'originalRxcui': '3...  309314       YES
# 4349  [{'activeRxcui': '993541', 'originalRxcui': '9...  993541       YES
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  OBSOLETE  00002324001
# 3        {'sourceName': ['MTHFDA', 'MTHSPL', 'RXNORM']}  OBSOLETE  00002324007
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002324033
# ...                                                 ...       ...          ...
# 4345               {'sourceName': ['MTHSPL', 'RXNORM']}  OBSOLETE  75921064830
# 4346  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  OBSOLETE  76282020601
# 4347  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  OBSOLETE  76282020701
# 4348  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  OBSOLETE  76282020801
# 4349               {'sourceName': ['MTHSPL', 'RXNORM']}  OBSOLETE  76519102105
#
# [4350 rows x 12 columns]

# %%
df_active = df_status.loc[df_status['active']== 'YES'].reset_index(drop=True)

# %%
df_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0       YES     NO    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 1       YES     NO    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 3       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 4       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 2617    YES     NO    None                      fluoxetine 10 MG Oral Capsule
# 2618    YES     NO    None                      fluoxetine 20 MG Oral Capsule
# 2619    YES     NO    None                      fluoxetine 20 MG Oral Capsule
# 2620    YES     NO    None                      fluoxetine 20 MG Oral Capsule
# 2621    YES     NO    None  24 HR bupropion hydrochloride 150 MG Extended ...
#
#      conceptStatus        ndc11  \
# 0           ACTIVE  00002323101
# 1           ACTIVE  00002323133
# 2           ACTIVE  00002323301
# 3           ACTIVE  00002323330
# 4           ACTIVE  00002323333
# ...            ...          ...
# 2617        ACTIVE  76365010106
# 2618        ACTIVE  76365010202
# 2619        ACTIVE  76365010204
# 2620        ACTIVE  76365010206
# 2621        ACTIVE  76519102103
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 3     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 2617  [{'activeRxcui': '310384', 'originalRxcui': '3...  310384       YES
# 2618  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2619  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2620  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2621  [{'activeRxcui': '993541', 'originalRxcui': '9...  993541       YES
#
#                                              sourceList  status          ndc
# 0     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...  ACTIVE  00002323101
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323133
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  ACTIVE  00002323301
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323330
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323333
# ...                                                 ...     ...          ...
# 2617        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010106
# 2618        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010202
# 2619        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010204
# 2620        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010206
# 2621        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519102103
#
# [2622 rows x 12 columns]

# %%
df_not_active = df_status.loc[df_status['active']!= 'YES'].reset_index(drop=True)

# %%
df_not_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0        NO     NO    None  fluoxetine 90 MG Delayed Release Oral Capsule ...
# 1        NO     NO    None  fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...
# 2        NO     NO    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 3        NO     NO    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# 4        NO     NO    None  duloxetine 30 MG Delayed Release Oral Capsule ...
# ...     ...    ...     ...                                                ...
# 4661                  None
# 4662                  None
# 4663                  None
# 4664                  None
# 4665                  None
#
#      conceptStatus        ndc11  \
# 0         OBSOLETE  00002300475
# 1         OBSOLETE  00002323230
# 2           ACTIVE  00002324001
# 3           ACTIVE  00002324007
# 4           ACTIVE  00002324033
# ...            ...          ...
# 4661
# 4662
# 4663
# 4664
# 4665
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '', 'originalRxcui': '598032'...  598032       YES
# 1     [{'activeRxcui': '', 'originalRxcui': '725076'...  725076       YES
# 2     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 3     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# 4     [{'activeRxcui': '596932', 'originalRxcui': '5...  596932       YES
# ...                                                 ...     ...       ...
# 4661                                                NaN
# 4662                                                NaN
# 4663                                                NaN
# 4664                                                NaN
# 4665                                                NaN
#
#                                              sourceList    status          ndc
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002300475
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002323230
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  OBSOLETE  00002324001
# 3        {'sourceName': ['MTHFDA', 'MTHSPL', 'RXNORM']}  OBSOLETE  00002324007
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE  00002324033
# ...                                                 ...       ...          ...
# 4661                                                 {}   UNKNOWN      2200177
# 4662                                                 {}   UNKNOWN      2200178
# 4663                                                 {}   UNKNOWN      2200180
# 4664                                                 {}   UNKNOWN      2200181
# 4665                                                 {}   UNKNOWN      2200183
#
# [4666 rows x 12 columns]

# %%
df_active.to_excel("active.xlsx",index=False)
df_not_active.to_excel("NOT_active.xlsx",index=False)

# %%
df_not_active_blank = df_not_active.loc[df_not_active['active']!= 'NO'].reset_index(drop=True)

# %%
df_not_active_blank
# Out:
#     active altNdc comment conceptName conceptStatus ndc11 ndcHistory rxcui  \
# 0                    None                                        NaN
# 1                    None                                        NaN
# 2                    None                                        NaN
# 3                    None                                        NaN
# 4                    None                                        NaN
# ..     ...    ...     ...         ...           ...   ...        ...   ...
# 311                  None                                        NaN
# 312                  None                                        NaN
# 313                  None                                        NaN
# 314                  None                                        NaN
# 315                  None                                        NaN
#
#     rxnormNdc sourceList   status      ndc
# 0                     {}  UNKNOWN   104836
# 1                     {}  UNKNOWN   104837
# 2                     {}  UNKNOWN   104838
# 3                     {}  UNKNOWN   104849
# 4                     {}  UNKNOWN   106834
# ..        ...        ...      ...      ...
# 311                   {}  UNKNOWN  2200177
# 312                   {}  UNKNOWN  2200178
# 313                   {}  UNKNOWN  2200180
# 314                   {}  UNKNOWN  2200181
# 315                   {}  UNKNOWN  2200183
#
# [316 rows x 12 columns]

# %%
df_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0       YES     NO    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 1       YES     NO    None  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 3       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 4       YES     NO    None  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 2617    YES     NO    None                      fluoxetine 10 MG Oral Capsule
# 2618    YES     NO    None                      fluoxetine 20 MG Oral Capsule
# 2619    YES     NO    None                      fluoxetine 20 MG Oral Capsule
# 2620    YES     NO    None                      fluoxetine 20 MG Oral Capsule
# 2621    YES     NO    None  24 HR bupropion hydrochloride 150 MG Extended ...
#
#      conceptStatus        ndc11  \
# 0           ACTIVE  00002323101
# 1           ACTIVE  00002323133
# 2           ACTIVE  00002323301
# 3           ACTIVE  00002323330
# 4           ACTIVE  00002323333
# ...            ...          ...
# 2617        ACTIVE  76365010106
# 2618        ACTIVE  76365010202
# 2619        ACTIVE  76365010204
# 2620        ACTIVE  76365010206
# 2621        ACTIVE  76519102103
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 3     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 2617  [{'activeRxcui': '310384', 'originalRxcui': '3...  310384       YES
# 2618  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2619  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2620  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2621  [{'activeRxcui': '993541', 'originalRxcui': '9...  993541       YES
#
#                                              sourceList  status          ndc
# 0     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...  ACTIVE  00002323101
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323133
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  ACTIVE  00002323301
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323330
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323333
# ...                                                 ...     ...          ...
# 2617        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010106
# 2618        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010202
# 2619        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010204
# 2620        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010206
# 2621        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519102103
#
# [2622 rows x 12 columns]

# %%
df_active=pd.read_excel("active.xlsx", dtype="object")

# %%
df_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0       YES     NO     NaN  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 1       YES     NO     NaN  fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...
# 2       YES     NO     NaN  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 3       YES     NO     NaN  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# 4       YES     NO     NaN  fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...
# ...     ...    ...     ...                                                ...
# 2617    YES     NO     NaN                      fluoxetine 10 MG Oral Capsule
# 2618    YES     NO     NaN                      fluoxetine 20 MG Oral Capsule
# 2619    YES     NO     NaN                      fluoxetine 20 MG Oral Capsule
# 2620    YES     NO     NaN                      fluoxetine 20 MG Oral Capsule
# 2621    YES     NO     NaN  24 HR bupropion hydrochloride 150 MG Extended ...
#
#      conceptStatus        ndc11  \
# 0           ACTIVE  00002323101
# 1           ACTIVE  00002323133
# 2           ACTIVE  00002323301
# 3           ACTIVE  00002323330
# 4           ACTIVE  00002323333
# ...            ...          ...
# 2617        ACTIVE  76365010106
# 2618        ACTIVE  76365010202
# 2619        ACTIVE  76365010204
# 2620        ACTIVE  76365010206
# 2621        ACTIVE  76519102103
#
#                                              ndcHistory   rxcui rxnormNdc  \
# 0     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 1     [{'activeRxcui': '725064', 'originalRxcui': '7...  725064       YES
# 2     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 3     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# 4     [{'activeRxcui': '725072', 'originalRxcui': '7...  725072       YES
# ...                                                 ...     ...       ...
# 2617  [{'activeRxcui': '310384', 'originalRxcui': '3...  310384       YES
# 2618  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2619  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2620  [{'activeRxcui': '310385', 'originalRxcui': '3...  310385       YES
# 2621  [{'activeRxcui': '993541', 'originalRxcui': '9...  993541       YES
#
#                                              sourceList  status          ndc
# 0     {'sourceName': ['GS', 'MTHFDA', 'MTHSPL', 'RXN...  ACTIVE  00002323101
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323133
# 2     {'sourceName': ['GS', 'MMX', 'MTHFDA', 'MTHSPL...  ACTIVE  00002323301
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323330
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  ACTIVE  00002323333
# ...                                                 ...     ...          ...
# 2617        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010106
# 2618        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010202
# 2619        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010204
# 2620        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76365010206
# 2621        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519102103
#
# [2622 rows x 12 columns]

# %%
i = 0
df_search=pd.DataFrame()
for code in df_active["ndc"]:
    ndc = code
    if ndc[0] == "0":
        ndc=ndc[1:]
        #4-4-2
        ndc = ndc[:4]+'-'+ ndc[4:8]+'-'+ndc[8:]
    elif ndc[9]!="0":
        #5-3-2
        ndc = ndc[:5]+'-'+ ndc[6:9]+'-'+ndc[9:]
    elif ndc[5]=="0":
        #identify whether it is 5-4 or 5-3
        #5-4
        ndc4=ndc[:5]+"-"+ndc[5:9]
        #5-3
        ndc3=ndc[:5]+'-'+ ndc[6:9]
        try:
            flag4 = pd.read_json("https://api.fda.gov/drug/ndc.json?search=product_ndc:{}".format(ndc4), orient='values', typ='series', convert_dates=False)
        except:
            flag4=pd.DataFrame()
        try:
            flag3 = pd.read_json("https://api.fda.gov/drug/ndc.json?search=product_ndc:{}".format(ndc3), orient='values', typ='series', convert_dates=False)
        except:
            flag3=pd.DataFrame()
        if (flag3.empty is True and flag4.empty is True):
            #if the product does not exist the ndc will be set to 0 because the package will not exist
            ndc = "0"
        elif flag3.empty == False:
            #5-3-2
            ndc = ndc[:5]+'-'+ ndc[6:9]+'-'+ndc[9:]
        elif flag4.empty== False:
            #5-4-1
            ndc=ndc[:5]+"-"+ndc[5:9]+'-'+ndc[10:]
        else:
            print("Duplicate Flag")
    elif ndc[9]=="0":
        ndc=ndc[:5]+"-"+ndc[5:9]+'-'+ndc[10:]
    else:
        print("ndc error: "+ndc)
    df_A = pd.DataFrame()
    try:
        df_A = pd.read_json("https://api.fda.gov/drug/ndc.json?search=packaging.package_ndc:{}".format(ndc), orient='values', typ='series', convert_dates=False)
        df_A = pd.DataFrame(df_A.results)
    except:
        i+=1
    df_search = pd.concat([df_search,df_A]).reset_index(drop=True)

# %%
df_search
# Out:
#   product_ndc                   generic_name    labeler_name brand_name  \
# 0   0456-1101       vilazodone hydrochloride  Allergan, Inc.    VIIBRYD
# 1   0456-2202  LEVOMILNACIPRAN HYDROCHLORIDE  Allergan, Inc.    Fetzima
#
#    finished                                          packaging  \
# 0      True  [{'package_ndc': '0456-1101-30', 'description'...
# 1      True  [{'package_ndc': '0456-2202-28', 'description'...
#
#   listing_expiration_date                                            openfda  \
# 0                20231231  {'manufacturer_name': ['Allergan, Inc.'], 'rxc...
# 1                20231231  {'manufacturer_name': ['Allergan, Inc.'], 'rxc...
#
#   marketing_category dosage_form                                spl_id  \
# 0                NDA         KIT  541fee02-b5a1-44a8-afe5-123c141c6272
# 1                NDA         KIT  4edbf1f8-ca28-43a7-9257-0951af75ec53
#
#               product_type   route marketing_start_date  \
# 0  HUMAN PRESCRIPTION DRUG  [ORAL]             20110429
# 1  HUMAN PRESCRIPTION DRUG  [ORAL]             20130725
#
#                                        product_id application_number  \
# 0  0456-1101_541fee02-b5a1-44a8-afe5-123c141c6272          NDA022567
# 1  0456-2202_4edbf1f8-ca28-43a7-9257-0951af75ec53          NDA204168
#
#   brand_name_base
# 0         VIIBRYD
# 1         Fetzima

# %%
pd.read_json("https://api.fda.gov/drug/ndc.json?search=packaging.package_ndc:{}".format("0456-1101-30"), orient='values', typ='series', convert_dates=False).results
# Out:
# [{'product_ndc': '0456-1101',
#   'generic_name': 'vilazodone hydrochloride',
#   'labeler_name': 'Allergan, Inc.',
#   'brand_name': 'VIIBRYD',
#   'finished': True,
#   'packaging': [{'package_ndc': '0456-1101-30',
#     'description': '1 KIT in 1 BLISTER PACK (0456-1101-30)',
#     'marketing_start_date': '20110429',
#     'sample': False}],
#   'listing_expiration_date': '20231231',
#   'openfda': {'manufacturer_name': ['Allergan, Inc.'],
#    'rxcui': ['1086772',
#     '1086776',
#     '1086778',
#     '1086780',
#     '1086784',
#     '1086786',
#     '1086789',
#     '1086790',
#     '1653469',
#     '1653470'],
#    'spl_set_id': ['4c55ccfb-c4cf-11df-851a-0800200c9a66'],
#    'is_original_packager': [True],
#    'upc': ['0304561110308', '0304561120307', '0304561140305'],
#    'unii': ['U8HTX2GK8J']},
#   'marketing_category': 'NDA',
#   'dosage_form': 'KIT',
#   'spl_id': '541fee02-b5a1-44a8-afe5-123c141c6272',
#   'product_type': 'HUMAN PRESCRIPTION DRUG',
#   'route': ['ORAL'],
#   'marketing_start_date': '20110429',
#   'product_id': '0456-1101_541fee02-b5a1-44a8-afe5-123c141c6272',
#   'application_number': 'NDA022567',
#   'brand_name_base': 'VIIBRYD'}]

# %%
df_search.to_excel("error.xlsx", index=False)
