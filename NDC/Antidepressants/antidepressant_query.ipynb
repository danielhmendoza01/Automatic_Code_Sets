# %%
import pandas as pd

# %%
#Global paramenters
#API URLs from RxNorm
base_endpoint = "https://api.fda.gov/drug/ndc.json?search=active_ingredients.name:"
limit = "&limit=1000"
#dataframe
df = pd.DataFrame()

# %%
#Method to get all drugs with an opioid ingredient
def query_drug(name_of_drug):
    row = 0
    df = pd.DataFrame()
    df = pd.read_json(base_endpoint+name_of_drug+limit, orient='values', typ='series', convert_dates=False)
    new_df = pd.DataFrame(df.results)
    return new_df

# %%
ingredients = ["5-hydroxytryptophan","amitriptyline","amoxapine","brexanolone","bupropion","citalopram","clomipramine","desipramine","desvenlafaxine","dothiepin","doxepin","duloxetine","escitalopram","esketamine","fluoxetine","fluvoxamine","imipramine","isocarboxazid","levomilnacipran","maprotiline","milnacipran","mirtazapine","nefazodone","nortriptyline","opipramol","paroxetine","phenelzine","protriptyline","selegiline","sertraline","St.+John's+wort+extract","tianeptine","tranylcypromine","trazodone","trimipramine","tryptophan","venlafaxine","vilazodone","viloxazine","vortioxetine"]

# %%
df_anti = pd.DataFrame()
for drug in ingredients:
    print(drug)
    merg_df = query_drug(drug)
    df_anti = pd.concat([df_anti, merg_df]).drop_duplicates(subset=['product_ndc']).reset_index(drop=True)
df_anti
# Out:
# 5-hydroxytryptophan
# amitriptyline
# amoxapine
# brexanolone
# bupropion
# citalopram
# clomipramine
# desipramine
# desvenlafaxine
# dothiepin
# doxepin
# duloxetine
# escitalopram
# esketamine
# fluoxetine
# fluvoxamine
# imipramine
# isocarboxazid
# levomilnacipran
# maprotiline
# milnacipran
# mirtazapine
# nefazodone
# nortriptyline
# opipramol
# paroxetine
# phenelzine
# protriptyline
# selegiline
# sertraline
# St.+John's+wort+extract
# tianeptine
# tranylcypromine
# trazodone
# trimipramine
# tryptophan
# venlafaxine
# vilazodone
# viloxazine
# vortioxetine
#      product_ndc                                       generic_name  \
# 0      25357-022   riboflavin 5-phosphate in 20% dextran ophthalmic
# 1     43742-1396  Influenzinum (2018-2019), Adenoviren Nosode, H...
# 2      83021-300  Propylene Glycol, Glyceryl Stearate Se, Humulu...
# 3      83021-742  Cetearyl Ethylhexanoate, Propylene Glycol, Gly...
# 4     69497-0090                    pneumococcal vaccine polyvalent
# ...          ...                                                ...
# 4462  47234-4110                                       Vortioxetine
# 4463  47234-4120                                       Vortioxetine
# 4464  45562-1135                          Vortioxetine Hydrobromide
# 4465   53747-072                          Vortioxetine Hydrobromide
# 4466  68554-0110                          Vortioxetine Hydrobromide
#
#                                labeler_name                  brand_name  \
# 0                       Glaukos Corporation            Photrexa Viscous
# 1                 Deseret Biologicals, Inc.                  Virus Plus
# 2                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 3                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 4                      MSD Ireland (Carlow)                         NaN
# ...                                     ...                         ...
# 4462                            Takeda GmbH                         NaN
# 4463                            Takeda GmbH                         NaN
# 4464  Lundbeck Pharmaceuticals Italy S.p.A.                         NaN
# 4465    Unichem Laboratories Limited, India                         NaN
# 4466                    Hetero Labs Limited                         NaN
#
#                                      active_ingredients  finished  \
# 0     [{'name': 'RIBOFLAVIN 5'-PHOSPHATE SODIUM ANHY...      True
# 1     [{'name': 'HEPATITIS B VIRUS', 'strength': '33...      True
# 2     [{'name': 'ALCOHOL', 'strength': '.08 mL/200mL...      True
# 3     [{'name': '.ALPHA.-HEXYLCINNAMALDEHYDE', 'stre...      True
# 4     [{'name': 'STREPTOCOCCUS PNEUMONIAE TYPE 1 CAP...     False
# ...                                                 ...       ...
# 4462  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4463  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4464  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4465  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4466  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
#
#                                               packaging  \
# 0     [{'package_ndc': '25357-022-01', 'description'...
# 1     [{'package_ndc': '43742-1396-1', 'description'...
# 2     [{'package_ndc': '83021-300-01', 'description'...
# 3     [{'package_ndc': '83021-742-01', 'description'...
# 4     [{'package_ndc': '69497-0090-0', 'description'...
# ...                                                 ...
# 4462  [{'package_ndc': '47234-4110-1', 'description'...
# 4463  [{'package_ndc': '47234-4120-1', 'description'...
# 4464  [{'package_ndc': '45562-1135-0', 'description'...
# 4465  [{'package_ndc': '53747-072-00', 'description'...
# 4466  [{'package_ndc': '68554-0110-1', 'description'...
#
#      listing_expiration_date  \
# 0                   20231231
# 1                        NaN
# 2                   20231231
# 3                   20231231
# 4                   20221231
# ...                      ...
# 4462                20221231
# 4463                20221231
# 4464                20221231
# 4465                20231231
# 4466                20221231
#
#                                                 openfda  \
# 0     {'manufacturer_name': ['Glaukos Corporation'],...
# 1     {'manufacturer_name': ['Deseret Biologicals, I...
# 2     {'manufacturer_name': ['ANUBIS COSMETICS SL'],...
# 3     {'manufacturer_name': ['ANUBIS COSMETICS SL'],...
# 4                                                    {}
# ...                                                 ...
# 4462                                                 {}
# 4463                                                 {}
# 4464                                                 {}
# 4465                                                 {}
# 4466                                                 {}
#
#                marketing_category  ...                        product_type  \
# 0                             NDA  ...             HUMAN PRESCRIPTION DRUG
# 1          UNAPPROVED HOMEOPATHIC  ...                      HUMAN OTC DRUG
# 2             OTC MONOGRAPH FINAL  ...                      HUMAN OTC DRUG
# 3             OTC MONOGRAPH FINAL  ...                      HUMAN OTC DRUG
# 4     DRUG FOR FURTHER PROCESSING  ...  LICENSED VACCINE BULK INTERMEDIATE
# ...                           ...  ...                                 ...
# 4462  DRUG FOR FURTHER PROCESSING  ...         DRUG FOR FURTHER PROCESSING
# 4463  DRUG FOR FURTHER PROCESSING  ...         DRUG FOR FURTHER PROCESSING
# 4464  DRUG FOR FURTHER PROCESSING  ...         DRUG FOR FURTHER PROCESSING
# 4465              BULK INGREDIENT  ...                     BULK INGREDIENT
# 4466              BULK INGREDIENT  ...                     BULK INGREDIENT
#
#              route marketing_start_date  \
# 0     [OPHTHALMIC]             20160415
# 1           [ORAL]             20181102
# 2        [TOPICAL]             20221020
# 3        [TOPICAL]             20221019
# 4              NaN             19830707
# ...            ...                  ...
# 4462           NaN             20131002
# 4463           NaN             20131002
# 4464           NaN             20131205
# 4465           NaN             20170331
# 4466           NaN             20130930
#
#                                            product_id application_number  \
# 0      25357-022_030af81d-5c28-44e7-8386-6c5b3f569af0          NDA203324
# 1     43742-1396_a2ca13d3-8bf0-449f-b589-ad4f38872bef                NaN
# 2      83021-300_eb7c418b-8bef-26a3-e053-2a95a90a4e96               M006
# 3      83021-742_eb68c3ab-7836-1a1c-e053-2995a90a0d66               M006
# 4     69497-0090_03dd44f3-0290-4a2f-874c-649eb7f3d7b4                NaN
# ...                                               ...                ...
# 4462  47234-4110_7c7a4e85-b3b7-49bd-963d-791a4307104f                NaN
# 4463  47234-4120_7c7a4e85-b3b7-49bd-963d-791a4307104f                NaN
# 4464  45562-1135_4f780700-e06e-424b-843c-171628338b32                NaN
# 4465   53747-072_8a6520c6-8cda-4e9c-b89f-814a12318d54                NaN
# 4466  68554-0110_b902082e-a047-764b-e053-2995a90a1aef                NaN
#
#                  brand_name_base marketing_end_date  \
# 0               Photrexa Viscous                NaN
# 1                     Virus Plus           20231210
# 2     Anubis Barcelona Regul Oil                NaN
# 3     Anubis Barcelona Regul Oil                NaN
# 4                           None                NaN
# ...                          ...                ...
# 4462                        None                NaN
# 4463                        None                NaN
# 4464                        None                NaN
# 4465                        None                NaN
# 4466                        None                NaN
#
#                                             pharm_class brand_name_suffix  \
# 0                                                   NaN               NaN
# 1     [Actively Acquired Immunity [PE], Actively Acq...               NaN
# 2     [Allergens [CS], Allergens [CS], Allergens [CS...               NaN
# 3     [Allergens [CS], Allergens [CS], Allergens [CS...               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 4462                                                NaN               NaN
# 4463                                                NaN               NaN
# 4464                                                NaN               NaN
# 4465                                                NaN               NaN
# 4466                                                NaN               NaN
#
#      dea_schedule
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 4462          NaN
# 4463          NaN
# 4464          NaN
# 4465          NaN
# 4466          NaN
#
# [4467 rows x 22 columns]

# %%
#get within package
df_package = pd.DataFrame()
i = 0
while i < df_anti.shape[0]:
    df_temp = pd.DataFrame(df_anti.packaging[i])
    df_temp.insert(0,"generic_name", df_anti.generic_name[i])
    df_temp.insert(1,"labeler_name", df_anti.labeler_name[i])
    df_temp.insert(2,"brand_name", df_anti.brand_name[i])
    df_package = pd.concat([df_package, df_temp]).drop_duplicates(subset=['package_ndc']).reset_index(drop=True)
    i+=1
df_package
# Out:
#                                            generic_name  \
# 0      riboflavin 5-phosphate in 20% dextran ophthalmic
# 1     Influenzinum (2018-2019), Adenoviren Nosode, H...
# 2     Propylene Glycol, Glyceryl Stearate Se, Humulu...
# 3     Cetearyl Ethylhexanoate, Propylene Glycol, Gly...
# 4                       pneumococcal vaccine polyvalent
# ...                                                 ...
# 9428                                       Vortioxetine
# 9429                                       Vortioxetine
# 9430                          Vortioxetine Hydrobromide
# 9431                          Vortioxetine Hydrobromide
# 9432                          Vortioxetine Hydrobromide
#
#                                labeler_name                  brand_name  \
# 0                       Glaukos Corporation            Photrexa Viscous
# 1                 Deseret Biologicals, Inc.                  Virus Plus
# 2                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 3                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 4                      MSD Ireland (Carlow)                         NaN
# ...                                     ...                         ...
# 9428                            Takeda GmbH                         NaN
# 9429                            Takeda GmbH                         NaN
# 9430  Lundbeck Pharmaceuticals Italy S.p.A.                         NaN
# 9431    Unichem Laboratories Limited, India                         NaN
# 9432                    Hetero Labs Limited                         NaN
#
#        package_ndc                                        description  \
# 0     25357-022-01  10 POUCH in 1 BOX (25357-022-01)  > 1 POUCH in...
# 1     43742-1396-1          30 mL in 1 BOTTLE, DROPPER (43742-1396-1)
# 2     83021-300-01                    200 mL in 1 TUBE (83021-300-01)
# 3     83021-742-01                    200 mL in 1 TUBE (83021-742-01)
# 4     69497-0090-0  416 VIAL, SINGLE-DOSE in 1 TRAY (69497-0090-0)...
# ...            ...                                                ...
# 9428  47234-4110-1  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9429  47234-4120-1  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9430  45562-1135-0                     20 kg in 1 DRUM (45562-1135-0)
# 9431  53747-072-00   1 BAG in 1 DRUM (53747-072-00)  > 50 kg in 1 BAG
# 9432  68554-0110-1                      1 kg in 1 DRUM (68554-0110-1)
#
#      marketing_start_date sample marketing_end_date
# 0                20160415  False                NaN
# 1                20181102  False           20231210
# 2                20221020  False                NaN
# 3                20221019  False                NaN
# 4               07-JUL-83    NaN                NaN
# ...                   ...    ...                ...
# 9428            02-OCT-13    NaN                NaN
# 9429            02-OCT-13    NaN                NaN
# 9430            05-DEC-13    NaN                NaN
# 9431            31-MAR-17    NaN                NaN
# 9432            30-SEP-13    NaN                NaN
#
# [9433 rows x 8 columns]

# %%
#Change to NDC11
for ele in df_package.package_ndc:
    s = ele.split("-")
    S = []
    for i, L in enumerate([5,4,2]):
        if len(s[i]) < L:
            S.append('0'*(L-len(s[i])) + s[i])
        else:
            S.append(s[i])
    ndc11 = ''.join(S)
    df_package.replace(ele,ndc11, inplace=True)
df_package
# Out:
#                                            generic_name  \
# 0      riboflavin 5-phosphate in 20% dextran ophthalmic
# 1     Influenzinum (2018-2019), Adenoviren Nosode, H...
# 2     Propylene Glycol, Glyceryl Stearate Se, Humulu...
# 3     Cetearyl Ethylhexanoate, Propylene Glycol, Gly...
# 4                       pneumococcal vaccine polyvalent
# ...                                                 ...
# 9428                                       Vortioxetine
# 9429                                       Vortioxetine
# 9430                          Vortioxetine Hydrobromide
# 9431                          Vortioxetine Hydrobromide
# 9432                          Vortioxetine Hydrobromide
#
#                                labeler_name                  brand_name  \
# 0                       Glaukos Corporation            Photrexa Viscous
# 1                 Deseret Biologicals, Inc.                  Virus Plus
# 2                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 3                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 4                      MSD Ireland (Carlow)                         NaN
# ...                                     ...                         ...
# 9428                            Takeda GmbH                         NaN
# 9429                            Takeda GmbH                         NaN
# 9430  Lundbeck Pharmaceuticals Italy S.p.A.                         NaN
# 9431    Unichem Laboratories Limited, India                         NaN
# 9432                    Hetero Labs Limited                         NaN
#
#       package_ndc                                        description  \
# 0     25357002201  10 POUCH in 1 BOX (25357-022-01)  > 1 POUCH in...
# 1     43742139601          30 mL in 1 BOTTLE, DROPPER (43742-1396-1)
# 2     83021030001                    200 mL in 1 TUBE (83021-300-01)
# 3     83021074201                    200 mL in 1 TUBE (83021-742-01)
# 4     69497009000  416 VIAL, SINGLE-DOSE in 1 TRAY (69497-0090-0)...
# ...           ...                                                ...
# 9428  47234411001  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9429  47234412001  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9430  45562113500                     20 kg in 1 DRUM (45562-1135-0)
# 9431  53747007200   1 BAG in 1 DRUM (53747-072-00)  > 50 kg in 1 BAG
# 9432  68554011001                      1 kg in 1 DRUM (68554-0110-1)
#
#      marketing_start_date sample marketing_end_date
# 0                20160415  False                NaN
# 1                20181102  False           20231210
# 2                20221020  False                NaN
# 3                20221019  False                NaN
# 4               07-JUL-83    NaN                NaN
# ...                   ...    ...                ...
# 9428            02-OCT-13    NaN                NaN
# 9429            02-OCT-13    NaN                NaN
# 9430            05-DEC-13    NaN                NaN
# 9431            31-MAR-17    NaN                NaN
# 9432            30-SEP-13    NaN                NaN
#
# [9433 rows x 8 columns]

# %%
df_package.to_excel("ndc_antidepressants.xlsx", index=False)

# %%
df_package.drop(columns=["marketing_start_date"], inplace=True)

# %%
#com
df_cdc = pd.read_excel("HEDIS MY 2021 Medication List Directory 2021-03-31.xlsx", sheet_name="Medication Lists to Codes", dtype='object')
df_cdc
# Out:
#                 Medication List Name                Medication List OID  \
# 0                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 1                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 2                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 3                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 4                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# ...                              ...                                ...
# 224861  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224862  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224863                           NaN                                NaN
# 224864                           NaN                                NaN
# 224865                           NaN                                NaN
#
#        Medication List Version         Code            Generic Product Name  \
# 0                   2021-03-31  00006007107    finasteride 1 MG Oral Tablet
# 1                   2021-03-31  00006007131    finasteride 1 MG Oral Tablet
# 2                   2021-03-31  00006007154    finasteride 1 MG Oral Tablet
# 3                   2021-03-31  00006007231    finasteride 5 MG Oral Tablet
# 4                   2021-03-31  00006007258    finasteride 5 MG Oral Tablet
# ...                        ...          ...                             ...
# 224861              2021-03-31       313778  ziprasidone 80 MG Oral Capsule
# 224862              2021-03-31       314286  ziprasidone 20 MG Oral Capsule
# 224863                     NaN          NaN                             NaN
# 224864                                  NaN                             NaN
# 224865                                  NaN                             NaN
#
#                                      Brand Name Route Package Size Unit  \
# 0       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 1       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 2       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 3        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# 4        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# ...                                         ...   ...          ...  ...
# 224861                                      NaN  oral          NaN  NaN
# 224862                                      NaN  oral          NaN  NaN
# 224863                                      NaN   NaN          NaN  NaN
# 224864                                      NaN   NaN          NaN  NaN
# 224865                                      NaN   NaN          NaN  NaN
#
#        Code System         Code System OID Code System Version Drug Class
# 0              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...            ...                     ...                 ...        ...
# 224861      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224862      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224863         NaN                     NaN                 NaN        NaN
# 224864         NaN                     NaN                 NaN        NaN
# 224865         NaN                     NaN                 NaN        NaN
#
# [224866 rows x 13 columns]

# %%
df_cdc=df_cdc.loc[df_cdc['Medication List Name']=="Antidepressant Medications"]

# %%
df_cdc.reset_index(drop=True)
# Out:
#              Medication List Name                Medication List OID  \
# 0      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                           ...                                ...
# 12735  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12736  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12737  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12738  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12739  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#       Medication List Version         Code  \
# 0                  2021-03-31  00002300475
# 1                  2021-03-31  00002323030
# 2                  2021-03-31  00002323101
# 3                  2021-03-31  00002323130
# 4                  2021-03-31  00002323133
# ...                       ...          ...
# 12735              2021-03-31      2200177
# 12736              2021-03-31      2200178
# 12737              2021-03-31      2200180
# 12738              2021-03-31      2200181
# 12739              2021-03-31      2200183
#
#                                     Generic Product Name  \
# 0          fluoxetine 90 MG Delayed Release Oral Capsule
# 1        fluoxetine 25 MG / olanzapine 3 MG Oral Capsule
# 2        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 4        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# ...                                                  ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 12736  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12738  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                               Brand Name Route Package Size  \
# 0      fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1      fluoxetine 25 MG / olanzapine 3 MG Oral Capsul...  oral          NaN
# 2      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 4      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                  ...   ...          ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 12736                                                NaN  oral          NaN
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 12738                                                NaN  oral          NaN
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#       Unit Code System         Code System OID Code System Version Drug Class
# 0      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...    ...         ...                     ...                 ...        ...
# 12735  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12736  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12737  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12738  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12739  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [12740 rows x 13 columns]

# %%
#Identify new drugs found
same_drug_count = 0
new_drug_count = 0
drug_not_found_count = 0
same_drug = pd.DataFrame()
new_drug = pd.DataFrame()
for code in df_package['package_ndc']:
    if df_cdc.isin([str(code)]).any().any() == True:
        same_drug_count += 1
        same_drug = pd.concat([same_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
    else:
        new_drug_count += 1
        new_drug = pd.concat([new_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
print('Same drug count: ', same_drug_count)
print('New drug count: ', new_drug_count)
# Out:
# Same drug count:  5399
# New drug count:  4034

# %%
absent_drugs = pd.DataFrame()
count = 0
#for every code from the combind excel list
for code in df_cdc['Code']:
    if df_package.isin([str(code)]).any().any() == True:
        count+=1
    else:
        absent_drugs = pd.concat([absent_drugs, df_cdc.loc[df_cdc['Code']==code]]).reset_index(drop=True)
print('Count: ', count)
absent_drugs
# Out:
# Count:  5399
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7336  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7337  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7338  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7339  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7340  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7336              2021-03-31      2200177
# 7337              2021-03-31      2200178
# 7338              2021-03-31      2200180
# 7339              2021-03-31      2200181
# 7340              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7336  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7337  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7338  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7339  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7340  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7336  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7337                                                NaN  oral          NaN
# 7338  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7339                                                NaN  oral          NaN
# 7340  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7336  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7337  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7338  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7339  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7340  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7341 rows x 13 columns]

# %%
#export
same_drug.to_excel("Same_Antidepressants_Medications.xlsx", index=False)
new_drug.to_excel("New_Antidepressants_Added.xlsx", index=False)
absent_drugs.to_excel("Absent_Antidepressants.xlsx", index=False)

# %%
new_drug
# Out:
#                                            generic_name  \
# 0      riboflavin 5-phosphate in 20% dextran ophthalmic
# 1     Influenzinum (2018-2019), Adenoviren Nosode, H...
# 2     Propylene Glycol, Glyceryl Stearate Se, Humulu...
# 3     Cetearyl Ethylhexanoate, Propylene Glycol, Gly...
# 4                       pneumococcal vaccine polyvalent
# ...                                                 ...
# 4029                                       Vortioxetine
# 4030                                       Vortioxetine
# 4031                          Vortioxetine Hydrobromide
# 4032                          Vortioxetine Hydrobromide
# 4033                          Vortioxetine Hydrobromide
#
#                                labeler_name                  brand_name  \
# 0                       Glaukos Corporation            Photrexa Viscous
# 1                 Deseret Biologicals, Inc.                  Virus Plus
# 2                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 3                       ANUBIS COSMETICS SL  Anubis Barcelona Regul Oil
# 4                      MSD Ireland (Carlow)                         NaN
# ...                                     ...                         ...
# 4029                            Takeda GmbH                         NaN
# 4030                            Takeda GmbH                         NaN
# 4031  Lundbeck Pharmaceuticals Italy S.p.A.                         NaN
# 4032    Unichem Laboratories Limited, India                         NaN
# 4033                    Hetero Labs Limited                         NaN
#
#       package_ndc                                        description sample  \
# 0     25357002201  10 POUCH in 1 BOX (25357-022-01)  > 1 POUCH in...  False
# 1     43742139601          30 mL in 1 BOTTLE, DROPPER (43742-1396-1)  False
# 2     83021030001                    200 mL in 1 TUBE (83021-300-01)  False
# 3     83021074201                    200 mL in 1 TUBE (83021-742-01)  False
# 4     69497009000  416 VIAL, SINGLE-DOSE in 1 TRAY (69497-0090-0)...    NaN
# ...           ...                                                ...    ...
# 4029  47234411001  129450 TABLET, FILM COATED in 1 DRUM (47234-41...    NaN
# 4030  47234412001  129450 TABLET, FILM COATED in 1 DRUM (47234-41...    NaN
# 4031  45562113500                     20 kg in 1 DRUM (45562-1135-0)    NaN
# 4032  53747007200   1 BAG in 1 DRUM (53747-072-00)  > 50 kg in 1 BAG    NaN
# 4033  68554011001                      1 kg in 1 DRUM (68554-0110-1)    NaN
#
#      marketing_end_date
# 0                   NaN
# 1              20231210
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4029                NaN
# 4030                NaN
# 4031                NaN
# 4032                NaN
# 4033                NaN
#
# [4034 rows x 7 columns]
