# %%
import pandas as pd

# %%
#Global paramenters
#API URLs from RxNorm
base_endpoint = "https://api.fda.gov/drug/ndc.json?search=active_ingredients.name:"
limit = "&limit=1000"
#dataframe
df = pd.DataFrame()

# %%
#Method to get all drugs with an opioid ingredient
def query_drug(name_of_drug):
    row = 0
    df = pd.DataFrame()
    df = pd.read_json(base_endpoint+name_of_drug+limit, orient='values', typ='series', convert_dates=False)
    new_df = pd.DataFrame(df.results)
    return new_df

# %%
ingredients = ["5-hydroxytryptophan","amitriptyline","amoxapine","brexanolone","bupropion","citalopram","clomipramine","desipramine","desvenlafaxine","dothiepin","doxepin","duloxetine","escitalopram","esketamine","fluoxetine","fluvoxamine","imipramine","isocarboxazid","levomilnacipran","maprotiline","milnacipran","mirtazapine","nefazodone","nortriptyline","opipramol","paroxetine","phenelzine","protriptyline","selegiline","sertraline","St.+John's+wort+extract","tianeptine","tranylcypromine","trazodone","trimipramine","tryptophan","venlafaxine","vilazodone","viloxazine","vortioxetine"]

# %%
df_anti = pd.DataFrame()
for drug in ingredients:
    merg_df = query_drug(drug)
    df_anti = pd.concat([df_anti, merg_df]).drop_duplicates(subset=['product_ndc']).reset_index(drop=True)
df_anti
# Out:
#      product_ndc                                       generic_name  \
# 0     69497-0101                    pneumococcal vaccine polyvalent
# 1     43742-1117  Influenzinum (2017-2018), Adenoviren Nosode, H...
# 2     43742-1586  Influenzinum (2019-2020), Herpes Simplex 1 Nos...
# 3     44911-0517  Echinacea (Angustifolia), Lomatium Dissectum, ...
# 4     43742-1810                             Cytomegolavirus Nosode
# ...          ...                                                ...
# 4464   53747-072                          Vortioxetine Hydrobromide
# 4465  55154-0257                                       vortioxetine
# 4466  70518-2642                                       vortioxetine
# 4467  55154-0256                                       vortioxetine
# 4468  68554-0110                          Vortioxetine Hydrobromide
#
#                              labeler_name  \
# 0                    MSD Ireland (Carlow)
# 1               Deseret Biologicals, Inc.
# 2               Deseret Biologicals, Inc.
# 3                          Energique, Inc
# 4               Deseret Biologicals, Inc.
# ...                                   ...
# 4464  Unichem Laboratories Limited, India
# 4465             Cardinal Health 107, LLC
# 4466                    REMEDYREPACK INC.
# 4467             Cardinal Health 107, LLC
# 4468                  Hetero Labs Limited
#
#                                      active_ingredients  finished  \
# 0     [{'name': 'STREPTOCOCCUS PNEUMONIAE TYPE 1 CAP...     False
# 1     [{'name': 'HEPATITIS B VIRUS', 'strength': '33...      True
# 2     [{'name': 'HEPATITIS B VIRUS', 'strength': '33...      True
# 3     [{'name': 'ARANEUS DIADEMATUS', 'strength': '1...      True
# 4     [{'name': 'HUMAN HERPESVIRUS 5', 'strength': '...     False
# ...                                                 ...       ...
# 4464  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4465  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4466  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4467  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4468  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
#
#                                               packaging  \
# 0     [{'package_ndc': '69497-0101-0', 'description'...
# 1     [{'package_ndc': '43742-1117-1', 'description'...
# 2     [{'package_ndc': '43742-1586-1', 'description'...
# 3     [{'package_ndc': '44911-0517-1', 'description'...
# 4     [{'package_ndc': '43742-1810-1', 'description'...
# ...                                                 ...
# 4464  [{'package_ndc': '53747-072-00', 'description'...
# 4465  [{'package_ndc': '55154-0257-8', 'description'...
# 4466  [{'package_ndc': '70518-2642-0', 'description'...
# 4467  [{'package_ndc': '55154-0256-8', 'description'...
# 4468  [{'package_ndc': '68554-0110-1', 'description'...
#
#      listing_expiration_date  \
# 0                   20231231
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 4464                20231231
# 4465                20231231
# 4466                20231231
# 4467                20231231
# 4468                20221231
#
#                                                 openfda  \
# 0                                                    {}
# 1     {'manufacturer_name': ['Deseret Biologicals, I...
# 2     {'manufacturer_name': ['Deseret Biologicals, I...
# 3     {'manufacturer_name': ['Energique, Inc'], 'spl...
# 4                                                    {}
# ...                                                 ...
# 4464                                                 {}
# 4465  {'manufacturer_name': ['Cardinal Health 107, L...
# 4466  {'manufacturer_name': ['REMEDYREPACK INC.'], '...
# 4467  {'manufacturer_name': ['Cardinal Health 107, L...
# 4468                                                 {}
#
#                marketing_category          dosage_form  ...  \
# 0     DRUG FOR FURTHER PROCESSING  INJECTION, SOLUTION  ...
# 1          UNAPPROVED HOMEOPATHIC               LIQUID  ...
# 2          UNAPPROVED HOMEOPATHIC               LIQUID  ...
# 3          UNAPPROVED HOMEOPATHIC               LIQUID  ...
# 4     DRUG FOR FURTHER PROCESSING               LIQUID  ...
# ...                           ...                  ...  ...
# 4464              BULK INGREDIENT               POWDER  ...
# 4465                          NDA  TABLET, FILM COATED  ...
# 4466                          NDA  TABLET, FILM COATED  ...
# 4467                          NDA  TABLET, FILM COATED  ...
# 4468              BULK INGREDIENT               POWDER  ...
#
#      marketing_start_date                                       product_id  \
# 0                20140721  69497-0101_ccd3c2d7-02c8-4102-ada7-50f58e775563
# 1                20171214  43742-1117_64eac1e9-a72e-47a4-ac6b-fb2d7ad9e768
# 2                20191025  43742-1586_33825d85-931e-4e29-b472-7d7f367995bb
# 3                20191028  44911-0517_fa57f2f9-2353-48ab-ad5a-c51b9675632e
# 4                20210107  43742-1810_d112b6e9-e5ff-49bc-85ef-c85c1828b528
# ...                   ...                                              ...
# 4464             20170331   53747-072_8a6520c6-8cda-4e9c-b89f-814a12318d54
# 4465             20131002  55154-0257_38dd1664-d837-48c3-9239-e8f76f4c4bec
# 4466             20200324  70518-2642_dc760e13-7db8-3808-e053-2a95a90a9327
# 4467             20131002  55154-0256_38dd1664-d837-48c3-9239-e8f76f4c4bec
# 4468             20130930  68554-0110_b902082e-a047-764b-e053-2995a90a1aef
#
#         brand_name_base marketing_end_date         brand_name   route  \
# 0                  None                NaN                NaN     NaN
# 1            Virus Plus           20230822         Virus Plus  [ORAL]
# 2     Virus Combination           20250908  Virus Combination  [ORAL]
# 3              CMV Stat           20250203           CMV Stat  [ORAL]
# 4                  None           20260816                NaN     NaN
# ...                 ...                ...                ...     ...
# 4464               None                NaN                NaN     NaN
# 4465         Trintellix                NaN         Trintellix  [ORAL]
# 4466         Trintellix                NaN         Trintellix  [ORAL]
# 4467         Trintellix                NaN         Trintellix  [ORAL]
# 4468               None                NaN                NaN     NaN
#
#                                             pharm_class brand_name_suffix  \
# 0                                                   NaN               NaN
# 1     [Actively Acquired Immunity [PE], Actively Acq...               NaN
# 2     [Actively Acquired Immunity [PE], Actively Acq...               NaN
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 4464                                                NaN               NaN
# 4465                                                NaN               NaN
# 4466                                                NaN               NaN
# 4467                                                NaN               NaN
# 4468                                                NaN               NaN
#
#      application_number dea_schedule
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
# ...                 ...          ...
# 4464                NaN          NaN
# 4465          NDA204447          NaN
# 4466          NDA204447          NaN
# 4467          NDA204447          NaN
# 4468                NaN          NaN
#
# [4469 rows x 22 columns]

# %%
#get within package
df_package = pd.DataFrame()
i = 0
while i < df_anti.shape[0]:
    df_temp = pd.DataFrame(df_anti.packaging[i])
    df_temp.insert(0,"generic_name", df_anti.generic_name[i])
    df_temp.insert(1,"labeler_name", df_anti.labeler_name[i])
    df_temp.insert(2,"brand_name", df_anti.brand_name[i])
    df_package = pd.concat([df_package, df_temp]).drop_duplicates(subset=['package_ndc']).reset_index(drop=True)
    i+=1
df_package
# Out:
#                                            generic_name  \
# 0                       pneumococcal vaccine polyvalent
# 1     Influenzinum (2017-2018), Adenoviren Nosode, H...
# 2     Influenzinum (2019-2020), Herpes Simplex 1 Nos...
# 3     Echinacea (Angustifolia), Lomatium Dissectum, ...
# 4                                Cytomegolavirus Nosode
# ...                                                 ...
# 9538                          Vortioxetine Hydrobromide
# 9539                                       vortioxetine
# 9540                                       vortioxetine
# 9541                                       vortioxetine
# 9542                          Vortioxetine Hydrobromide
#
#                              labeler_name         brand_name   package_ndc  \
# 0                    MSD Ireland (Carlow)                NaN  69497-0101-0
# 1               Deseret Biologicals, Inc.         Virus Plus  43742-1117-1
# 2               Deseret Biologicals, Inc.  Virus Combination  43742-1586-1
# 3                          Energique, Inc           CMV Stat  44911-0517-1
# 4               Deseret Biologicals, Inc.                NaN  43742-1810-1
# ...                                   ...                ...           ...
# 9538  Unichem Laboratories Limited, India                NaN  53747-072-00
# 9539             Cardinal Health 107, LLC         Trintellix  55154-0257-8
# 9540                    REMEDYREPACK INC.         Trintellix  70518-2642-0
# 9541             Cardinal Health 107, LLC         Trintellix  55154-0256-8
# 9542                  Hetero Labs Limited                NaN  68554-0110-1
#
#                                             description marketing_start_date  \
# 0     100 SYRINGE, GLASS in 1 TRAY (69497-0101-0)  >...            21-JUL-14
# 1             30 mL in 1 BOTTLE, DROPPER (43742-1117-1)             20171214
# 2             30 mL in 1 BOTTLE, DROPPER (43742-1586-1)             20191025
# 3             30 mL in 1 BOTTLE, DROPPER (44911-0517-1)             20191028
# 4            960 mL in 1 BOTTLE, PLASTIC (43742-1810-1)            07-JAN-21
# ...                                                 ...                  ...
# 9538   1 BAG in 1 DRUM (53747-072-00)  > 50 kg in 1 BAG            31-MAR-17
# 9539  2430 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
# 9540  30 POUCH in 1 BOX (70518-2642-0)  > 1 TABLET, ...             20200324
# 9541  2520 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
# 9542                      1 kg in 1 DRUM (68554-0110-1)            30-SEP-13
#
#      marketing_end_date sample
# 0                   NaN    NaN
# 1              20230822  False
# 2              20250908  False
# 3              20250203  False
# 4             16-AUG-26    NaN
# ...                 ...    ...
# 9538                NaN    NaN
# 9539                NaN  False
# 9540                NaN  False
# 9541                NaN  False
# 9542                NaN    NaN
#
# [9543 rows x 8 columns]

# %%
#Change to NDC11
for ele in df_package.package_ndc:
    s = ele.split("-")
    S = []
    for i, L in enumerate([5,4,2]):
        if len(s[i]) < L:
            S.append('0'*(L-len(s[i])) + s[i])
        else:
            S.append(s[i])
    ndc11 = ''.join(S)
    df_package.replace(ele,ndc11, inplace=True)
df_package
# Out:
#                                            generic_name  \
# 0                       pneumococcal vaccine polyvalent
# 1     Influenzinum (2017-2018), Adenoviren Nosode, H...
# 2     Influenzinum (2019-2020), Herpes Simplex 1 Nos...
# 3     Echinacea (Angustifolia), Lomatium Dissectum, ...
# 4                                Cytomegolavirus Nosode
# ...                                                 ...
# 9538                          Vortioxetine Hydrobromide
# 9539                                       vortioxetine
# 9540                                       vortioxetine
# 9541                                       vortioxetine
# 9542                          Vortioxetine Hydrobromide
#
#                              labeler_name         brand_name  package_ndc  \
# 0                    MSD Ireland (Carlow)                NaN  69497010100
# 1               Deseret Biologicals, Inc.         Virus Plus  43742111701
# 2               Deseret Biologicals, Inc.  Virus Combination  43742158601
# 3                          Energique, Inc           CMV Stat  44911051701
# 4               Deseret Biologicals, Inc.                NaN  43742181001
# ...                                   ...                ...          ...
# 9538  Unichem Laboratories Limited, India                NaN  53747007200
# 9539             Cardinal Health 107, LLC         Trintellix  55154025708
# 9540                    REMEDYREPACK INC.         Trintellix  70518264200
# 9541             Cardinal Health 107, LLC         Trintellix  55154025608
# 9542                  Hetero Labs Limited                NaN  68554011001
#
#                                             description marketing_start_date  \
# 0     100 SYRINGE, GLASS in 1 TRAY (69497-0101-0)  >...            21-JUL-14
# 1             30 mL in 1 BOTTLE, DROPPER (43742-1117-1)             20171214
# 2             30 mL in 1 BOTTLE, DROPPER (43742-1586-1)             20191025
# 3             30 mL in 1 BOTTLE, DROPPER (44911-0517-1)             20191028
# 4            960 mL in 1 BOTTLE, PLASTIC (43742-1810-1)            07-JAN-21
# ...                                                 ...                  ...
# 9538   1 BAG in 1 DRUM (53747-072-00)  > 50 kg in 1 BAG            31-MAR-17
# 9539  2430 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
# 9540  30 POUCH in 1 BOX (70518-2642-0)  > 1 TABLET, ...             20200324
# 9541  2520 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
# 9542                      1 kg in 1 DRUM (68554-0110-1)            30-SEP-13
#
#      marketing_end_date sample
# 0                   NaN    NaN
# 1              20230822  False
# 2              20250908  False
# 3              20250203  False
# 4             16-AUG-26    NaN
# ...                 ...    ...
# 9538                NaN    NaN
# 9539                NaN  False
# 9540                NaN  False
# 9541                NaN  False
# 9542                NaN    NaN
#
# [9543 rows x 8 columns]

# %%
df_package.to_excel("ndc_antidepressants.xlsx", index=False)

# %%
#df_package.drop(columns=["marketing_start_date"], inplace=True)

# %%
#com
df_hedis = pd.read_excel("HEDIS MY 2021 Medication List Directory 2021-03-31.xlsx", sheet_name="Medication Lists to Codes", dtype='object')
df_hedis
# Out:
#                 Medication List Name                Medication List OID  \
# 0                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 1                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 2                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 3                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 4                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# ...                              ...                                ...
# 224861  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224862  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224863                           NaN                                NaN
# 224864                           NaN                                NaN
# 224865                           NaN                                NaN
#
#        Medication List Version         Code            Generic Product Name  \
# 0                   2021-03-31  00006007107    finasteride 1 MG Oral Tablet
# 1                   2021-03-31  00006007131    finasteride 1 MG Oral Tablet
# 2                   2021-03-31  00006007154    finasteride 1 MG Oral Tablet
# 3                   2021-03-31  00006007231    finasteride 5 MG Oral Tablet
# 4                   2021-03-31  00006007258    finasteride 5 MG Oral Tablet
# ...                        ...          ...                             ...
# 224861              2021-03-31       313778  ziprasidone 80 MG Oral Capsule
# 224862              2021-03-31       314286  ziprasidone 20 MG Oral Capsule
# 224863                     NaN          NaN                             NaN
# 224864                                  NaN                             NaN
# 224865                                  NaN                             NaN
#
#                                      Brand Name Route Package Size Unit  \
# 0       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 1       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 2       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 3        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# 4        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# ...                                         ...   ...          ...  ...
# 224861                                      NaN  oral          NaN  NaN
# 224862                                      NaN  oral          NaN  NaN
# 224863                                      NaN   NaN          NaN  NaN
# 224864                                      NaN   NaN          NaN  NaN
# 224865                                      NaN   NaN          NaN  NaN
#
#        Code System         Code System OID Code System Version Drug Class
# 0              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...            ...                     ...                 ...        ...
# 224861      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224862      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224863         NaN                     NaN                 NaN        NaN
# 224864         NaN                     NaN                 NaN        NaN
# 224865         NaN                     NaN                 NaN        NaN
#
# [224866 rows x 13 columns]

# %%
df_hedis = df_hedis.loc[df_hedis['Medication List Name']=="Antidepressant Medications"]

# %%
df_hedis.reset_index(drop=True)
# Out:
#              Medication List Name                Medication List OID  \
# 0      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                           ...                                ...
# 12735  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12736  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12737  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12738  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12739  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#       Medication List Version         Code  \
# 0                  2021-03-31  00002300475
# 1                  2021-03-31  00002323030
# 2                  2021-03-31  00002323101
# 3                  2021-03-31  00002323130
# 4                  2021-03-31  00002323133
# ...                       ...          ...
# 12735              2021-03-31      2200177
# 12736              2021-03-31      2200178
# 12737              2021-03-31      2200180
# 12738              2021-03-31      2200181
# 12739              2021-03-31      2200183
#
#                                     Generic Product Name  \
# 0          fluoxetine 90 MG Delayed Release Oral Capsule
# 1        fluoxetine 25 MG / olanzapine 3 MG Oral Capsule
# 2        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 4        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# ...                                                  ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 12736  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12738  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                               Brand Name Route Package Size  \
# 0      fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1      fluoxetine 25 MG / olanzapine 3 MG Oral Capsul...  oral          NaN
# 2      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 4      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                  ...   ...          ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 12736                                                NaN  oral          NaN
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 12738                                                NaN  oral          NaN
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#       Unit Code System         Code System OID Code System Version Drug Class
# 0      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...    ...         ...                     ...                 ...        ...
# 12735  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12736  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12737  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12738  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12739  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [12740 rows x 13 columns]

# %%
#Identify new drugs found
same_drug_count = 0
new_drug_count = 0
drug_not_found_count = 0
same_drug = pd.DataFrame()
new_drug = pd.DataFrame()
for code in df_package['package_ndc']:
    if df_hedis.isin([str(code)]).any().any() == True:
        same_drug_count += 1
        same_drug = pd.concat([same_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
    else:
        new_drug_count += 1
        new_drug = pd.concat([new_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
print('Same drug count: ', same_drug_count)
print('New drug count: ', new_drug_count)
# Out:
# Same drug count:  5407
# New drug count:  4136

# %%
absent_drugs = pd.DataFrame()
count = 0
#for every code from the combind excel list
for code in df_hedis['Code']:
    if df_package.isin([str(code)]).any().any() == True:
        count+=1
    else:
        absent_drugs = pd.concat([absent_drugs, df_hedis.loc[df_hedis['Code']==code]]).reset_index(drop=True)
print('Count: ', count)
absent_drugs
# Out:
# Count:  5407
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7328  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7329  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7330  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7331  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7332  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7328              2021-03-31      2200177
# 7329              2021-03-31      2200178
# 7330              2021-03-31      2200180
# 7331              2021-03-31      2200181
# 7332              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7328  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7329  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7330  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7331  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7332  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7328  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7329                                                NaN  oral          NaN
# 7330  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7331                                                NaN  oral          NaN
# 7332  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7328  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7329  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7330  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7331  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7332  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7333 rows x 13 columns]

# %%
#export
same_drug.to_excel("Same_Antidepressants_Medications.xlsx", index=False)
new_drug.to_excel("New_Antidepressants_Added.xlsx", index=False)
absent_drugs.to_excel("Absent_Antidepressants.xlsx", index=False)
