# %%
import pandas as pd

# %%
#Global paramenters
#API URLs from RxNorm
base_endpoint = "https://api.fda.gov/drug/ndc.json?search=active_ingredients.name:"
limit = "&limit=1000"
#dataframe
df = pd.DataFrame()

# %%
#Method to get all drugs with an opioid ingredient
def query_drug(name_of_drug):
    row = 0
    df = pd.DataFrame()
    df = pd.read_json(base_endpoint+name_of_drug+limit, orient='values', typ='series', convert_dates=False)
    new_df = pd.DataFrame(df.results)
    return new_df

# %%
ingredients = ["5-hydroxytryptophan","amitriptyline","amoxapine","brexanolone","bupropion","citalopram","clomipramine","desipramine","desvenlafaxine","dothiepin","doxepin","duloxetine","escitalopram","esketamine","fluoxetine","fluvoxamine","imipramine","isocarboxazid","levomilnacipran","maprotiline","milnacipran","mirtazapine","nefazodone","nortriptyline","opipramol","paroxetine","phenelzine","protriptyline","selegiline","sertraline","St.+John's+wort+extract","tianeptine","tranylcypromine","trazodone","trimipramine","tryptophan","venlafaxine","vilazodone","viloxazine","vortioxetine"]

# %%
df_anti = pd.DataFrame()
for drug in ingredients:
    print(drug)
    merg_df = query_drug(drug)
    df_anti = pd.concat([df_anti, merg_df]).drop_duplicates(subset=['product_ndc']).reset_index(drop=True)
df_anti
# Out:
# 5-hydroxytryptophan
# amitriptyline
# amoxapine
# brexanolone
# bupropion
# citalopram
# clomipramine
# desipramine
# desvenlafaxine
# dothiepin
# doxepin
# duloxetine
# escitalopram
# esketamine
# fluoxetine
# fluvoxamine
# imipramine
# isocarboxazid
# levomilnacipran
# maprotiline
# milnacipran
# mirtazapine
# nefazodone
# nortriptyline
# opipramol
# paroxetine
# phenelzine
# protriptyline
# selegiline
# sertraline
# St.+John's+wort+extract
# tianeptine
# tranylcypromine
# trazodone
# trimipramine
# tryptophan
# venlafaxine
# vilazodone
# viloxazine
# vortioxetine
#      product_ndc                                       generic_name  \
# 0     64181-0087                      RIBOFLAVIN 5-PHOSPHATE SODIUM
# 1      0006-4943                    pneumococcal vaccine polyvalent
# 2     51927-5136                       RIBOFLAVIN 5-PHOSPHATESODIUM
# 3     44911-0609  Echinacea (Angustifolia), Lomatium Dissectum, ...
# 4      68225-228  pneumococcal 15-valent conjugate vaccine crm19...
# ...          ...                                                ...
# 4443  70518-2642                                       vortioxetine
# 4444  47234-4105                                       Vortioxetine
# 4445  47234-4110                                       Vortioxetine
# 4446  47234-4120                                       Vortioxetine
# 4447  45562-1135                          Vortioxetine Hydrobromide
#
#                                      labeler_name  \
# 0                           Curia Wisconsin, Inc.
# 1                         Merck Sharp & Dohme LLC
# 2     Professional Compounding Centers of America
# 3                                  Energique, Inc
# 4                           Patheon Italia S.p.A.
# ...                                           ...
# 4443                            REMEDYREPACK INC.
# 4444                                  Takeda GmbH
# 4445                                  Takeda GmbH
# 4446                                  Takeda GmbH
# 4447        Lundbeck Pharmaceuticals Italy S.p.A.
#
#                                      active_ingredients  finished  \
# 0     [{'name': 'RIBOFLAVIN 5'-PHOSPHATE SODIUM', 's...     False
# 1     [{'name': 'STREPTOCOCCUS PNEUMONIAE TYPE 1 CAP...      True
# 2     [{'name': 'RIBOFLAVIN 5'-PHOSPHATE SODIUM', 's...     False
# 3     [{'name': 'ARANEUS DIADEMATUS', 'strength': '6...      True
# 4     [{'name': 'CORYNEBACTERIUM DIPHTHERIAE CRM197 ...     False
# ...                                                 ...       ...
# 4443  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4444  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4445  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4446  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4447  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
#
#                                               packaging  \
# 0     [{'package_ndc': '64181-0087-0', 'description'...
# 1     [{'package_ndc': '0006-4943-00', 'description'...
# 2     [{'package_ndc': '51927-5136-0', 'description'...
# 3     [{'package_ndc': '44911-0609-1', 'description'...
# 4     [{'package_ndc': '68225-228-00', 'description'...
# ...                                                 ...
# 4443  [{'package_ndc': '70518-2642-0', 'description'...
# 4444  [{'package_ndc': '47234-4105-1', 'description'...
# 4445  [{'package_ndc': '47234-4110-1', 'description'...
# 4446  [{'package_ndc': '47234-4120-1', 'description'...
# 4447  [{'package_ndc': '45562-1135-0', 'description'...
#
#      listing_expiration_date  \
# 0                   20221231
# 1                   20231231
# 2                   20221231
# 3                   20221231
# 4                   20231231
# ...                      ...
# 4443                20231231
# 4444                20221231
# 4445                20221231
# 4446                20221231
# 4447                20221231
#
#                                                 openfda  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3     {'manufacturer_name': ['Energique, Inc'], 'spl...
# 4                                                    {}
# ...                                                 ...
# 4443  {'manufacturer_name': ['REMEDYREPACK INC.'], '...
# 4444                                                 {}
# 4445                                                 {}
# 4446                                                 {}
# 4447                                                 {}
#
#                                      marketing_category  \
# 0                                       BULK INGREDIENT
# 1                                                   BLA
# 2     BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 3                                UNAPPROVED HOMEOPATHIC
# 4                           DRUG FOR FURTHER PROCESSING
# ...                                                 ...
# 4443                                                NDA
# 4444                        DRUG FOR FURTHER PROCESSING
# 4445                        DRUG FOR FURTHER PROCESSING
# 4446                        DRUG FOR FURTHER PROCESSING
# 4447                        DRUG FOR FURTHER PROCESSING
#
#                 dosage_form  ... marketing_start_date  \
# 0                    POWDER  ...             20040130
# 1       INJECTION, SOLUTION  ...             19830707
# 2                    POWDER  ...             20210331
# 3                    LIQUID  ...             20210524
# 4     INJECTION, SUSPENSION  ...             20210716
# ...                     ...  ...                  ...
# 4443    TABLET, FILM COATED  ...             20200324
# 4444    TABLET, FILM COATED  ...             20131002
# 4445    TABLET, FILM COATED  ...             20131002
# 4446    TABLET, FILM COATED  ...             20131002
# 4447                 POWDER  ...             20131205
#
#                                            product_id  brand_name_base  \
# 0     64181-0087_cbaa7f3a-c4b2-41cb-e053-2a95a90a4118             None
# 1      0006-4943_317a2dc7-b213-4058-8f85-5ad7cb86cd97     PNEUMOVAX 23
# 2     51927-5136_bed6ab66-a2c4-8fca-e053-2995a90a6210             None
# 3     44911-0609_9d55eff0-388f-42f5-839f-16c2c9812b23  Fatigue Stat CM
# 4      68225-228_ff646d4b-0b7a-49a5-8696-46ef210cc3d4             None
# ...                                               ...              ...
# 4443  70518-2642_dc760e13-7db8-3808-e053-2a95a90a9327       Trintellix
# 4444  47234-4105_7c7a4e85-b3b7-49bd-963d-791a4307104f             None
# 4445  47234-4110_7c7a4e85-b3b7-49bd-963d-791a4307104f             None
# 4446  47234-4120_7c7a4e85-b3b7-49bd-963d-791a4307104f             None
# 4447  45562-1135_4f780700-e06e-424b-843c-171628338b32             None
#
#            brand_name                          route application_number  \
# 0                 NaN                            NaN                NaN
# 1        PNEUMOVAX 23  [INTRAMUSCULAR, SUBCUTANEOUS]          BLA101094
# 2                 NaN                            NaN                NaN
# 3     Fatigue Stat CM                         [ORAL]                NaN
# 4                 NaN                            NaN                NaN
# ...               ...                            ...                ...
# 4443       Trintellix                         [ORAL]          NDA204447
# 4444              NaN                            NaN                NaN
# 4445              NaN                            NaN                NaN
# 4446              NaN                            NaN                NaN
# 4447              NaN                            NaN                NaN
#
#                                             pharm_class brand_name_suffix  \
# 0                                                   NaN               NaN
# 1     [Actively Acquired Immunity [PE], Actively Acq...               NaN
# 2                                                   NaN               NaN
# 3                                                   NaN               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 4443                                                NaN               NaN
# 4444                                                NaN               NaN
# 4445                                                NaN               NaN
# 4446                                                NaN               NaN
# 4447                                                NaN               NaN
#
#      marketing_end_date dea_schedule
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
# ...                 ...          ...
# 4443                NaN          NaN
# 4444                NaN          NaN
# 4445                NaN          NaN
# 4446                NaN          NaN
# 4447                NaN          NaN
#
# [4448 rows x 22 columns]

# %%
#get within package
df_package = pd.DataFrame()
i = 0
while i < df_anti.shape[0]:
    df_temp = pd.DataFrame(df_anti.packaging[i])
    df_package = pd.concat([df_package, df_temp]).drop_duplicates(subset=['package_ndc']).reset_index(drop=True)
    i+=1
df_package
# Out:
#        package_ndc                                        description  \
# 0     64181-0087-0                    .16 kg in 1 DRUM (64181-0087-0)
# 1     0006-4943-00  10 VIAL, SINGLE-DOSE in 1 CARTON (0006-4943-00...
# 2     51927-5136-0                    1 kg in 1 BOTTLE (51927-5136-0)
# 3     44911-0609-1          30 mL in 1 BOTTLE, DROPPER (44911-0609-1)
# 4     68225-228-00  100 SYRINGE, GLASS in 1 CASE (68225-228-00)  >...
# ...            ...                                                ...
# 9441  70518-2642-0  30 POUCH in 1 BOX (70518-2642-0)  > 1 TABLET, ...
# 9442  47234-4105-1  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9443  47234-4110-1  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9444  47234-4120-1  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9445  45562-1135-0                     20 kg in 1 DRUM (45562-1135-0)
#
#      marketing_start_date sample marketing_end_date
# 0               30-JAN-04    NaN                NaN
# 1                19830707  False                NaN
# 2               31-MAR-21    NaN                NaN
# 3                20210524  False                NaN
# 4               16-JUL-21    NaN                NaN
# ...                   ...    ...                ...
# 9441             20200324  False                NaN
# 9442            02-OCT-13    NaN                NaN
# 9443            02-OCT-13    NaN                NaN
# 9444            02-OCT-13    NaN                NaN
# 9445            05-DEC-13    NaN                NaN
#
# [9446 rows x 5 columns]

# %%
#Change to NDC11
for ele in df_package.package_ndc:
    s = ele.split("-")
    S = []
    for i, L in enumerate([5,4,2]):
        if len(s[i]) < L:
            S.append('0'*(L-len(s[i])) + s[i])
        else:
            S.append(s[i])
    ndc11 = ''.join(S)
    df_package.replace(ele,ndc11, inplace=True)
df_package
# Out:
#       package_ndc                                        description  \
# 0     64181008700                    .16 kg in 1 DRUM (64181-0087-0)
# 1     00006494300  10 VIAL, SINGLE-DOSE in 1 CARTON (0006-4943-00...
# 2     51927513600                    1 kg in 1 BOTTLE (51927-5136-0)
# 3     44911060901          30 mL in 1 BOTTLE, DROPPER (44911-0609-1)
# 4     68225022800  100 SYRINGE, GLASS in 1 CASE (68225-228-00)  >...
# ...           ...                                                ...
# 9441  70518264200  30 POUCH in 1 BOX (70518-2642-0)  > 1 TABLET, ...
# 9442  47234410501  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9443  47234411001  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9444  47234412001  129450 TABLET, FILM COATED in 1 DRUM (47234-41...
# 9445  45562113500                     20 kg in 1 DRUM (45562-1135-0)
#
#      marketing_start_date sample marketing_end_date
# 0               30-JAN-04    NaN                NaN
# 1                19830707  False                NaN
# 2               31-MAR-21    NaN                NaN
# 3                20210524  False                NaN
# 4               16-JUL-21    NaN                NaN
# ...                   ...    ...                ...
# 9441             20200324  False                NaN
# 9442            02-OCT-13    NaN                NaN
# 9443            02-OCT-13    NaN                NaN
# 9444            02-OCT-13    NaN                NaN
# 9445            05-DEC-13    NaN                NaN
#
# [9446 rows x 5 columns]

# %%
df_package.to_excel("ndc_antidepressants.xlsx", index=False)

# %%
#com
df_cdc = pd.read_excel("HEDIS MY 2021 Medication List Directory 2021-03-31.xlsx", sheet_name="Medication Lists to Codes", dtype='object')
df_cdc
# Out:
#                 Medication List Name                Medication List OID  \
# 0                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 1                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 2                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 3                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 4                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# ...                              ...                                ...
# 224861  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224862  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224863                           NaN                                NaN
# 224864                           NaN                                NaN
# 224865                           NaN                                NaN
#
#        Medication List Version         Code            Generic Product Name  \
# 0                   2021-03-31  00006007107    finasteride 1 MG Oral Tablet
# 1                   2021-03-31  00006007131    finasteride 1 MG Oral Tablet
# 2                   2021-03-31  00006007154    finasteride 1 MG Oral Tablet
# 3                   2021-03-31  00006007231    finasteride 5 MG Oral Tablet
# 4                   2021-03-31  00006007258    finasteride 5 MG Oral Tablet
# ...                        ...          ...                             ...
# 224861              2021-03-31       313778  ziprasidone 80 MG Oral Capsule
# 224862              2021-03-31       314286  ziprasidone 20 MG Oral Capsule
# 224863                     NaN          NaN                             NaN
# 224864                                  NaN                             NaN
# 224865                                  NaN                             NaN
#
#                                      Brand Name Route Package Size Unit  \
# 0       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 1       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 2       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 3        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# 4        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# ...                                         ...   ...          ...  ...
# 224861                                      NaN  oral          NaN  NaN
# 224862                                      NaN  oral          NaN  NaN
# 224863                                      NaN   NaN          NaN  NaN
# 224864                                      NaN   NaN          NaN  NaN
# 224865                                      NaN   NaN          NaN  NaN
#
#        Code System         Code System OID Code System Version Drug Class
# 0              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...            ...                     ...                 ...        ...
# 224861      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224862      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224863         NaN                     NaN                 NaN        NaN
# 224864         NaN                     NaN                 NaN        NaN
# 224865         NaN                     NaN                 NaN        NaN
#
# [224866 rows x 13 columns]

# %%
#Identify new drugs found
same_drug_count = 0
new_drug_count = 0
drug_not_found_count = 0
same_drug = pd.DataFrame()
new_drug = pd.DataFrame()
for code in df_package['package_ndc']:
    if df_cdc.isin([str(code)]).any().any() == True:
        same_drug_count += 1
        same_drug = pd.concat([same_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
    else:
        new_drug_count += 1
        new_drug = pd.concat([new_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
print('Same drug count: ', same_drug_count)
print('New drug count: ', new_drug_count)

# %%
absent_drugs = pd.DataFrame()
count = 0
#for every code from the combind excel list
for code in df_cdc['NDC']:
    if df_package.isin([str(code)]).any().any() == True:
        count+=1
    else:
        absent_drugs = pd.concat([absent_drugs, df_cdc.loc[df_cdc['NDC']==code]]).reset_index(drop=True)
print('Count: ', count)
absent_drugs

# %%
#export
same_drug.to_excel("Same_Opioid_Medications.xlsx", index=False)
new_drug.to_excel("New_Opioids_Added.xlsx", index=False)
absent_drugs.to_excel("Absent_Opioid.xlsx", index=False)
