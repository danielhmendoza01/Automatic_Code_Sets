# %%
import pandas as pd

# %%
#Global paramenters
#API URLs from RxNorm
base_endpoint = "https://api.fda.gov/drug/ndc.json?search=active_ingredients.name:"
limit = "&limit=1000"
#dataframe
df = pd.DataFrame()

# %%
#Method to get all drugs with an opioid ingredient
def query_drug(name_of_drug):
    row = 0
    df = pd.DataFrame()
    df = pd.read_json(base_endpoint+name_of_drug+limit, orient='values', typ='series', convert_dates=False)
    new_df = pd.DataFrame(df.results)
    return new_df

# %%
ingredients = ["5-hydroxytryptophan","amitriptyline","amoxapine","brexanolone","bupropion","citalopram","clomipramine","desipramine","desvenlafaxine","dothiepin","doxepin","duloxetine","escitalopram","esketamine","fluoxetine","fluvoxamine","imipramine","isocarboxazid","levomilnacipran","maprotiline","milnacipran","mirtazapine","nefazodone","nortriptyline","opipramol","paroxetine","phenelzine","protriptyline","selegiline","sertraline","St.+John's+wort+extract","tianeptine","tranylcypromine","trazodone","trimipramine","tryptophan","venlafaxine","vilazodone","viloxazine","vortioxetine"]

# %%
df_anti = pd.DataFrame()
for drug in ingredients:
    merg_df = query_drug(drug)
    df_anti = pd.concat([df_anti, merg_df]).reset_index(drop=True)
df_anti
# Out:
#      product_ndc                                       generic_name  \
# 0     38779-2529                                VersaPro Cream Base
# 1     69497-0090                    pneumococcal vaccine polyvalent
# 2     69497-0101                    pneumococcal vaccine polyvalent
# 3     69497-0134  Pneumococcal 15-valent Conjugate Vaccine CRM19...
# 4     63083-6017                            Viral Immune Stimulator
# ...          ...                                                ...
# 4526   64764-720                                       vortioxetine
# 4527   64764-750                                       vortioxetine
# 4528  68554-0110                          Vortioxetine Hydrobromide
# 4529  55154-0257                                       vortioxetine
# 4530  55154-0256                                       vortioxetine
#
#                                     labeler_name  \
# 0                                   Medisca Inc.
# 1                           MSD Ireland (Carlow)
# 2                           MSD Ireland (Carlow)
# 3                           MSD Ireland (Carlow)
# 4     Professional Complementary Health Formulas
# ...                                          ...
# 4526        Takeda Pharmaceuticals America, Inc.
# 4527        Takeda Pharmaceuticals America, Inc.
# 4528                         Hetero Labs Limited
# 4529                    Cardinal Health 107, LLC
# 4530                    Cardinal Health 107, LLC
#
#                                      active_ingredients  finished  \
# 0     [{'name': '.ALPHA.-TOCOPHEROL ACETATE', 'stren...     False
# 1     [{'name': 'STREPTOCOCCUS PNEUMONIAE TYPE 1 CAP...     False
# 2     [{'name': 'STREPTOCOCCUS PNEUMONIAE TYPE 1 CAP...     False
# 3     [{'name': 'CORYNEBACTERIUM DIPHTHERIAE CRM197 ...     False
# 4     [{'name': 'ASCLEPIAS TUBEROSA FLOWERING TOP', ...      True
# ...                                                 ...       ...
# 4526  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4527  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4528  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 4529  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 4530  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
#
#                                               packaging  \
# 0     [{'package_ndc': '38779-2529-1', 'description'...
# 1     [{'package_ndc': '69497-0090-0', 'description'...
# 2     [{'package_ndc': '69497-0101-0', 'description'...
# 3     [{'package_ndc': '69497-0134-0', 'description'...
# 4     [{'package_ndc': '63083-6017-2', 'description'...
# ...                                                 ...
# 4526  [{'package_ndc': '64764-720-07', 'description'...
# 4527  [{'package_ndc': '64764-750-07', 'description'...
# 4528  [{'package_ndc': '68554-0110-1', 'description'...
# 4529  [{'package_ndc': '55154-0257-8', 'description'...
# 4530  [{'package_ndc': '55154-0256-8', 'description'...
#
#      listing_expiration_date  \
# 0                   20231231
# 1                   20231231
# 2                   20231231
# 3                   20231231
# 4                   20231231
# ...                      ...
# 4526                20231231
# 4527                20231231
# 4528                20221231
# 4529                20231231
# 4530                20231231
#
#                                                 openfda  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'manufacturer_name': ['Professional Complemen...
# ...                                                 ...
# 4526  {'manufacturer_name': ['Takeda Pharmaceuticals...
# 4527  {'manufacturer_name': ['Takeda Pharmaceuticals...
# 4528                                                 {}
# 4529  {'manufacturer_name': ['Cardinal Health 107, L...
# 4530  {'manufacturer_name': ['Cardinal Health 107, L...
#
#                                      marketing_category  \
# 0     BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...
# 1                           DRUG FOR FURTHER PROCESSING
# 2                           DRUG FOR FURTHER PROCESSING
# 3                           DRUG FOR FURTHER PROCESSING
# 4                                UNAPPROVED HOMEOPATHIC
# ...                                                 ...
# 4526                                                NDA
# 4527                                                NDA
# 4528                                    BULK INGREDIENT
# 4529                                                NDA
# 4530                                                NDA
#
#                 dosage_form  ... marketing_start_date  \
# 0                     CREAM  ...             20140514
# 1       INJECTION, SOLUTION  ...             19830707
# 2       INJECTION, SOLUTION  ...             20140721
# 3     INJECTION, SUSPENSION  ...             20210718
# 4                    LIQUID  ...             19840815
# ...                     ...  ...                  ...
# 4526    TABLET, FILM COATED  ...             20131002
# 4527    TABLET, FILM COATED  ...             20131002
# 4528                 POWDER  ...             20130930
# 4529    TABLET, FILM COATED  ...             20131002
# 4530    TABLET, FILM COATED  ...             20131002
#
#                                            product_id  \
# 0     38779-2529_b94332a6-e31a-915d-e053-2995a90a8b2d
# 1     69497-0090_03dd44f3-0290-4a2f-874c-649eb7f3d7b4
# 2     69497-0101_ccd3c2d7-02c8-4102-ada7-50f58e775563
# 3     69497-0134_98ecda57-f2fb-427f-a196-b38a12e24cbd
# 4     63083-6017_1cbdad05-c611-45a3-831a-eb508e7408ff
# ...                                               ...
# 4526   64764-720_9694b181-c82e-48bb-afc2-895c74bafc68
# 4527   64764-750_9694b181-c82e-48bb-afc2-895c74bafc68
# 4528  68554-0110_b902082e-a047-764b-e053-2995a90a1aef
# 4529  55154-0257_38dd1664-d837-48c3-9239-e8f76f4c4bec
# 4530  55154-0256_38dd1664-d837-48c3-9239-e8f76f4c4bec
#
#               brand_name_base                    brand_name brand_name_suffix  \
# 0                        None                           NaN               NaN
# 1                        None                           NaN               NaN
# 2                        None                           NaN               NaN
# 3                        None                           NaN               NaN
# 4     Viral Immune Stimulator  Viral Immune Stimulator 6017              6017
# ...                       ...                           ...               ...
# 4526               Trintellix                    Trintellix               NaN
# 4527               Trintellix                    Trintellix               NaN
# 4528                     None                           NaN               NaN
# 4529               Trintellix                    Trintellix               NaN
# 4530               Trintellix                    Trintellix               NaN
#
#        route                                        pharm_class  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4     [ORAL]  [Actively Acquired Immunity [PE], Actively Acq...
# ...      ...                                                ...
# 4526  [ORAL]                                                NaN
# 4527  [ORAL]                                                NaN
# 4528     NaN                                                NaN
# 4529  [ORAL]                                                NaN
# 4530  [ORAL]                                                NaN
#
#      marketing_end_date application_number dea_schedule
# 0                   NaN                NaN          NaN
# 1                   NaN                NaN          NaN
# 2                   NaN                NaN          NaN
# 3                   NaN                NaN          NaN
# 4                   NaN                NaN          NaN
# ...                 ...                ...          ...
# 4526                NaN          NDA204447          NaN
# 4527                NaN          NDA204447          NaN
# 4528                NaN                NaN          NaN
# 4529                NaN          NDA204447          NaN
# 4530                NaN          NDA204447          NaN
#
# [4531 rows x 22 columns]

# %%
#get within package
df_package = pd.DataFrame()
i = 0
while i < df_anti.shape[0]:
    df_temp = pd.DataFrame(df_anti.packaging[i])
    df_temp.insert(0,"generic_name", df_anti.generic_name[i])
    df_temp.insert(1,"labeler_name", df_anti.labeler_name[i])
    df_temp.insert(2,"brand_name", df_anti.brand_name[i])
    df_package = pd.concat([df_package, df_temp]).drop_duplicates(subset=['package_ndc']).reset_index(drop=True)
    i+=1
df_package
# Out:
#                    generic_name                          labeler_name  \
# 0           VersaPro Cream Base                          Medisca Inc.
# 1           VersaPro Cream Base                          Medisca Inc.
# 2           VersaPro Cream Base                          Medisca Inc.
# 3           VersaPro Cream Base                          Medisca Inc.
# 4           VersaPro Cream Base                          Medisca Inc.
# ...                         ...                                   ...
# 9525               vortioxetine  Takeda Pharmaceuticals America, Inc.
# 9526               vortioxetine  Takeda Pharmaceuticals America, Inc.
# 9527  Vortioxetine Hydrobromide                   Hetero Labs Limited
# 9528               vortioxetine              Cardinal Health 107, LLC
# 9529               vortioxetine              Cardinal Health 107, LLC
#
#       brand_name   package_ndc  \
# 0            NaN  38779-2529-1
# 1            NaN  38779-2529-3
# 2            NaN  38779-2529-5
# 3            NaN  38779-2529-6
# 4            NaN  38779-2529-7
# ...          ...           ...
# 9525  Trintellix  64764-750-77
# 9526  Trintellix  64764-750-90
# 9527         NaN  68554-0110-1
# 9528  Trintellix  55154-0257-8
# 9529  Trintellix  55154-0256-8
#
#                                             description marketing_start_date  \
# 0                       2500 g in 1 PAIL (38779-2529-1)            14-MAY-14
# 1                       5000 g in 1 PAIL (38779-2529-3)            14-MAY-14
# 2                         100 g in 1 JAR (38779-2529-5)            14-MAY-14
# 3                         200 g in 1 JAR (38779-2529-6)            14-MAY-14
# 4                      20000 g in 1 DRUM (38779-2529-7)            14-MAY-14
# ...                                                 ...                  ...
# 9525  500 TABLET, FILM COATED in 1 BOTTLE (64764-750...             20131002
# 9526  90 TABLET, FILM COATED in 1 BOTTLE (64764-750-90)             20131002
# 9527                      1 kg in 1 DRUM (68554-0110-1)            30-SEP-13
# 9528  2430 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
# 9529  2520 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
#
#      sample marketing_end_date
# 0       NaN                NaN
# 1       NaN                NaN
# 2       NaN                NaN
# 3       NaN                NaN
# 4       NaN                NaN
# ...     ...                ...
# 9525  False                NaN
# 9526  False                NaN
# 9527    NaN                NaN
# 9528  False                NaN
# 9529  False                NaN
#
# [9530 rows x 8 columns]

# %%
#Change to NDC11
for ele in df_package.package_ndc:
    s = ele.split("-")
    S = []
    for i, L in enumerate([5,4,2]):
        if len(s[i]) < L:
            S.append('0'*(L-len(s[i])) + s[i])
        else:
            S.append(s[i])
    ndc11 = ''.join(S)
    df_package.replace(ele,ndc11, inplace=True)
df_package
# Out:
#                    generic_name                          labeler_name  \
# 0           VersaPro Cream Base                          Medisca Inc.
# 1           VersaPro Cream Base                          Medisca Inc.
# 2           VersaPro Cream Base                          Medisca Inc.
# 3           VersaPro Cream Base                          Medisca Inc.
# 4           VersaPro Cream Base                          Medisca Inc.
# ...                         ...                                   ...
# 9525               vortioxetine  Takeda Pharmaceuticals America, Inc.
# 9526               vortioxetine  Takeda Pharmaceuticals America, Inc.
# 9527  Vortioxetine Hydrobromide                   Hetero Labs Limited
# 9528               vortioxetine              Cardinal Health 107, LLC
# 9529               vortioxetine              Cardinal Health 107, LLC
#
#       brand_name  package_ndc  \
# 0            NaN  38779252901
# 1            NaN  38779252903
# 2            NaN  38779252905
# 3            NaN  38779252906
# 4            NaN  38779252907
# ...          ...          ...
# 9525  Trintellix  64764075077
# 9526  Trintellix  64764075090
# 9527         NaN  68554011001
# 9528  Trintellix  55154025708
# 9529  Trintellix  55154025608
#
#                                             description marketing_start_date  \
# 0                       2500 g in 1 PAIL (38779-2529-1)            14-MAY-14
# 1                       5000 g in 1 PAIL (38779-2529-3)            14-MAY-14
# 2                         100 g in 1 JAR (38779-2529-5)            14-MAY-14
# 3                         200 g in 1 JAR (38779-2529-6)            14-MAY-14
# 4                      20000 g in 1 DRUM (38779-2529-7)            14-MAY-14
# ...                                                 ...                  ...
# 9525  500 TABLET, FILM COATED in 1 BOTTLE (64764-750...             20131002
# 9526  90 TABLET, FILM COATED in 1 BOTTLE (64764-750-90)             20131002
# 9527                      1 kg in 1 DRUM (68554-0110-1)            30-SEP-13
# 9528  2430 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
# 9529  2520 TABLET, FILM COATED in 1 BOTTLE, PLASTIC ...             20131002
#
#      sample marketing_end_date
# 0       NaN                NaN
# 1       NaN                NaN
# 2       NaN                NaN
# 3       NaN                NaN
# 4       NaN                NaN
# ...     ...                ...
# 9525  False                NaN
# 9526  False                NaN
# 9527    NaN                NaN
# 9528  False                NaN
# 9529  False                NaN
#
# [9530 rows x 8 columns]

# %%
df_package.to_excel("ndc_antidepressants.xlsx", index=False)

# %%
#com
df_hedis = pd.read_excel("HEDIS MY 2021 Medication List Directory 2021-03-31.xlsx", sheet_name="Medication Lists to Codes", dtype='object')
df_hedis
# Out:
#                 Medication List Name                Medication List OID  \
# 0                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 1                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 2                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 3                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 4                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# ...                              ...                                ...
# 224861  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224862  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224863                           NaN                                NaN
# 224864                           NaN                                NaN
# 224865                           NaN                                NaN
#
#        Medication List Version         Code            Generic Product Name  \
# 0                   2021-03-31  00006007107    finasteride 1 MG Oral Tablet
# 1                   2021-03-31  00006007131    finasteride 1 MG Oral Tablet
# 2                   2021-03-31  00006007154    finasteride 1 MG Oral Tablet
# 3                   2021-03-31  00006007231    finasteride 5 MG Oral Tablet
# 4                   2021-03-31  00006007258    finasteride 5 MG Oral Tablet
# ...                        ...          ...                             ...
# 224861              2021-03-31       313778  ziprasidone 80 MG Oral Capsule
# 224862              2021-03-31       314286  ziprasidone 20 MG Oral Capsule
# 224863                     NaN          NaN                             NaN
# 224864                                  NaN                             NaN
# 224865                                  NaN                             NaN
#
#                                      Brand Name Route Package Size Unit  \
# 0       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 1       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 2       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 3        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# 4        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# ...                                         ...   ...          ...  ...
# 224861                                      NaN  oral          NaN  NaN
# 224862                                      NaN  oral          NaN  NaN
# 224863                                      NaN   NaN          NaN  NaN
# 224864                                      NaN   NaN          NaN  NaN
# 224865                                      NaN   NaN          NaN  NaN
#
#        Code System         Code System OID Code System Version Drug Class
# 0              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...            ...                     ...                 ...        ...
# 224861      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224862      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224863         NaN                     NaN                 NaN        NaN
# 224864         NaN                     NaN                 NaN        NaN
# 224865         NaN                     NaN                 NaN        NaN
#
# [224866 rows x 13 columns]

# %%
df_hedis = df_hedis.loc[df_hedis['Medication List Name']=="Antidepressant Medications"]

# %%
df_hedis.reset_index(drop=True)
# Out:
#              Medication List Name                Medication List OID  \
# 0      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                           ...                                ...
# 12735  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12736  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12737  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12738  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12739  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#       Medication List Version         Code  \
# 0                  2021-03-31  00002300475
# 1                  2021-03-31  00002323030
# 2                  2021-03-31  00002323101
# 3                  2021-03-31  00002323130
# 4                  2021-03-31  00002323133
# ...                       ...          ...
# 12735              2021-03-31      2200177
# 12736              2021-03-31      2200178
# 12737              2021-03-31      2200180
# 12738              2021-03-31      2200181
# 12739              2021-03-31      2200183
#
#                                     Generic Product Name  \
# 0          fluoxetine 90 MG Delayed Release Oral Capsule
# 1        fluoxetine 25 MG / olanzapine 3 MG Oral Capsule
# 2        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 4        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# ...                                                  ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 12736  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12738  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                               Brand Name Route Package Size  \
# 0      fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1      fluoxetine 25 MG / olanzapine 3 MG Oral Capsul...  oral          NaN
# 2      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 4      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                  ...   ...          ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 12736                                                NaN  oral          NaN
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 12738                                                NaN  oral          NaN
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#       Unit Code System         Code System OID Code System Version Drug Class
# 0      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...    ...         ...                     ...                 ...        ...
# 12735  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12736  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12737  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12738  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12739  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [12740 rows x 13 columns]

# %%
#Identify new drugs found
same_drug_count = 0
new_drug_count = 0
drug_not_found_count = 0
same_drug = pd.DataFrame()
new_drug = pd.DataFrame()
for code in df_package['package_ndc']:
    if df_hedis.isin([str(code)]).any().any() == True:
        same_drug_count += 1
        same_drug = pd.concat([same_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
    else:
        new_drug_count += 1
        new_drug = pd.concat([new_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
print('Same drug count: ', same_drug_count)
print('New drug count: ', new_drug_count)
# Out:
# Same drug count:  5458
# New drug count:  4072

# %%
absent_drugs = pd.DataFrame()
count = 0
#for every code from the combind excel list
for code in df_hedis['Code']:
    if df_package.isin([str(code)]).any().any() == True:
        count+=1
    else:
        absent_drugs = pd.concat([absent_drugs, df_hedis.loc[df_hedis['Code']==code]]).reset_index(drop=True)
print('Count: ', count)
absent_drugs
# Out:
# Count:  5458
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7277  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7278  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7279  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7280  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7281  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7277              2021-03-31      2200177
# 7278              2021-03-31      2200178
# 7279              2021-03-31      2200180
# 7280              2021-03-31      2200181
# 7281              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7277  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7278  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7279  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7280  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7281  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7277  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7278                                                NaN  oral          NaN
# 7279  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7280                                                NaN  oral          NaN
# 7281  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7277  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7278  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7279  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7280  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7281  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7282 rows x 13 columns]

# %%
#export
same_drug.to_excel("Same_Antidepressants_Medications.xlsx", index=False)
new_drug.to_excel("New_Antidepressants_Added.xlsx", index=False)
absent_drugs.to_excel("Absent_Antidepressants.xlsx", index=False)

# %%
absent_drugs
# Out:
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7277  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7278  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7279  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7280  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7281  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7277              2021-03-31      2200177
# 7278              2021-03-31      2200178
# 7279              2021-03-31      2200180
# 7280              2021-03-31      2200181
# 7281              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7277  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7278  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7279  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7280  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7281  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7277  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7278                                                NaN  oral          NaN
# 7279  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7280                                                NaN  oral          NaN
# 7281  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7277  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7278  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7279  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7280  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7281  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7282 rows x 13 columns]
