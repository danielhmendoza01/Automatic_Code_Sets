# %%
import pandas as pd

# %%
#Global paramenters
#API URLs from RxNorm
base_endpoint = "https://api.fda.gov/drug/ndc.json?search=active_ingredients.name:"
limit = "&limit=1000"
#dataframe
df = pd.DataFrame()

# %%
#Method to get all drugs with an opioid ingredient
def query_drug(name_of_drug):
    row = 0
    df = pd.DataFrame()
    df = pd.read_json(base_endpoint+name_of_drug+limit, orient='values', typ='series', convert_dates=False)
    new_df = pd.DataFrame(df.results)
    return new_df

# %%
ingredients = ["\"5-hydroxytryptophan\"","amitriptyline","amoxapine","brexanolone","bupropion","citalopram","clomipramine","desipramine","desvenlafaxine","dothiepin","doxepin","duloxetine","escitalopram","esketamine","fluoxetine","fluvoxamine","imipramine","isocarboxazid","levomilnacipran","maprotiline","milnacipran","mirtazapine","nefazodone","nortriptyline","opipramol","paroxetine","phenelzine","protriptyline","selegiline","sertraline","\"ST.+JOHN'S+WORT\"","tianeptine","tranylcypromine","trazodone","trimipramine","tryptophan","venlafaxine","vilazodone","viloxazine","vortioxetine"]

# %%
df_anti = pd.DataFrame()
for drug in ingredients:
    merg_df = query_drug(drug)
    df_anti = pd.concat([df_anti, merg_df]).reset_index(drop=True)
df_anti
# Out:
#      product_ndc                                       generic_name  \
# 0      17089-265  5-hydroxy tryptophan,dl - alfalfa - avena sati...
# 1     51927-1603                        AMITRIPTYLINE HYDROCHLORIDE
# 2     63629-3597                        Amitriptyline Hydrochloride
# 3     67296-0932                        Amitriptyline Hydrochloride
# 4     50090-3784                        Amitriptyline Hydrochloride
# ...          ...                                                ...
# 3466   64764-730                                       vortioxetine
# 3467   42973-236                          VORTIOXETINE HYDROBROMIDE
# 3468  47234-4120                                       Vortioxetine
# 3469  47234-4105                                       Vortioxetine
# 3470  47234-4110                                       Vortioxetine
#
#                                            labeler_name  \
# 0                                              Guna spa
# 1     Professional Compounding Centers of America db...
# 2                                  Bryant Ranch Prepack
# 3                                   RedPharm Drug, Inc.
# 4                              A-S Medication Solutions
# ...                                                 ...
# 3466               Takeda Pharmaceuticals America, Inc.
# 3467            APICORE PHARMACEUTICALS PRIVATE LIMITED
# 3468                                        Takeda GmbH
# 3469                                        Takeda GmbH
# 3470                                        Takeda GmbH
#
#                        brand_name  \
# 0                       GUNA-MOOD
# 1                             NaN
# 2     Amitriptyline Hydrochloride
# 3     Amitriptyline Hydrochloride
# 4     Amitriptyline Hydrochloride
# ...                           ...
# 3466                   Trintellix
# 3467                          NaN
# 3468                          NaN
# 3469                          NaN
# 3470                          NaN
#
#                                      active_ingredients  finished  \
# 0     [{'name': '5-HYDROXYTRYPTOPHAN, DL-', 'strengt...      True
# 1     [{'name': 'AMITRIPTYLINE HYDROCHLORIDE', 'stre...     False
# 2     [{'name': 'AMITRIPTYLINE HYDROCHLORIDE', 'stre...      True
# 3     [{'name': 'AMITRIPTYLINE HYDROCHLORIDE', 'stre...      True
# 4     [{'name': 'AMITRIPTYLINE HYDROCHLORIDE', 'stre...      True
# ...                                                 ...       ...
# 3466  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...      True
# 3467  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 3468  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 3469  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
# 3470  [{'name': 'VORTIOXETINE HYDROBROMIDE', 'streng...     False
#
#                                               packaging  \
# 0     [{'package_ndc': '17089-265-18', 'description'...
# 1     [{'package_ndc': '51927-1603-0', 'description'...
# 2     [{'package_ndc': '63629-3597-1', 'description'...
# 3     [{'package_ndc': '67296-0932-1', 'description'...
# 4     [{'package_ndc': '50090-3784-0', 'description'...
# ...                                                 ...
# 3466  [{'package_ndc': '64764-730-07', 'description'...
# 3467  [{'package_ndc': '42973-236-00', 'description'...
# 3468  [{'package_ndc': '47234-4120-1', 'description'...
# 3469  [{'package_ndc': '47234-4105-1', 'description'...
# 3470  [{'package_ndc': '47234-4110-1', 'description'...
#
#      listing_expiration_date  \
# 0                   20231231
# 1                   20221231
# 2                   20231231
# 3                   20231231
# 4                   20221231
# ...                      ...
# 3466                20231231
# 3467                20231231
# 3468                20221231
# 3469                20221231
# 3470                20221231
#
#                                                 openfda  \
# 0     {'manufacturer_name': ['Guna spa'], 'spl_set_i...
# 1                                                    {}
# 2     {'manufacturer_name': ['Bryant Ranch Prepack']...
# 3     {'manufacturer_name': ['RedPharm Drug, Inc.'],...
# 4     {'manufacturer_name': ['A-S Medication Solutio...
# ...                                                 ...
# 3466  {'manufacturer_name': ['Takeda Pharmaceuticals...
# 3467                                                 {}
# 3468                                                 {}
# 3469                                                 {}
# 3470                                                 {}
#
#                                      marketing_category  ...  \
# 0                                UNAPPROVED HOMEOPATHIC  ...
# 1     BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUN...  ...
# 2                                                  ANDA  ...
# 3                                                  ANDA  ...
# 4                                                  ANDA  ...
# ...                                                 ...  ...
# 3466                                                NDA  ...
# 3467                                    BULK INGREDIENT  ...
# 3468                        DRUG FOR FURTHER PROCESSING  ...
# 3469                        DRUG FOR FURTHER PROCESSING  ...
# 3470                        DRUG FOR FURTHER PROCESSING  ...
#
#                      product_type   route marketing_start_date  \
# 0                  HUMAN OTC DRUG  [ORAL]             20060523
# 1                 BULK INGREDIENT     NaN             20130620
# 2         HUMAN PRESCRIPTION DRUG  [ORAL]             19771129
# 3         HUMAN PRESCRIPTION DRUG  [ORAL]             19771121
# 4         HUMAN PRESCRIPTION DRUG  [ORAL]             20171226
# ...                           ...     ...                  ...
# 3466      HUMAN PRESCRIPTION DRUG  [ORAL]             20131002
# 3467              BULK INGREDIENT     NaN             20170601
# 3468  DRUG FOR FURTHER PROCESSING     NaN             20131002
# 3469  DRUG FOR FURTHER PROCESSING     NaN             20131002
# 3470  DRUG FOR FURTHER PROCESSING     NaN             20131002
#
#                                            product_id  \
# 0      17089-265_ed71627c-52fb-5ac2-e053-2a95a90ac90b
# 1     51927-1603_43229621-6a89-4073-ae17-33b8dd491eae
# 2     63629-3597_46c2a8a1-3f7d-4660-b5d6-73de13b4a060
# 3     67296-0932_d60f7de8-3a78-bbfb-e053-2995a90a2674
# 4     50090-3784_57b2f786-4dbc-457c-ae5e-8ca637e0ee14
# ...                                               ...
# 3466   64764-730_9694b181-c82e-48bb-afc2-895c74bafc68
# 3467   42973-236_ec4f5bac-38e2-501b-e053-2995a90a48c5
# 3468  47234-4120_7c7a4e85-b3b7-49bd-963d-791a4307104f
# 3469  47234-4105_7c7a4e85-b3b7-49bd-963d-791a4307104f
# 3470  47234-4110_7c7a4e85-b3b7-49bd-963d-791a4307104f
#
#                   brand_name_base application_number  \
# 0                       GUNA-MOOD                NaN
# 1                            None                NaN
# 2     Amitriptyline Hydrochloride         ANDA085968
# 3     Amitriptyline Hydrochloride         ANDA085969
# 4     Amitriptyline Hydrochloride         ANDA210086
# ...                           ...                ...
# 3466                   Trintellix          NDA204447
# 3467                         None                NaN
# 3468                         None                NaN
# 3469                         None                NaN
# 3470                         None                NaN
#
#                            pharm_class dea_schedule marketing_end_date  \
# 0                                  NaN          NaN                NaN
# 1                                  NaN          NaN                NaN
# 2     [Tricyclic Antidepressant [EPC]]          NaN                NaN
# 3     [Tricyclic Antidepressant [EPC]]          NaN                NaN
# 4     [Tricyclic Antidepressant [EPC]]          NaN                NaN
# ...                                ...          ...                ...
# 3466                               NaN          NaN                NaN
# 3467                               NaN          NaN                NaN
# 3468                               NaN          NaN                NaN
# 3469                               NaN          NaN                NaN
# 3470                               NaN          NaN                NaN
#
#      brand_name_suffix
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 3466               NaN
# 3467               NaN
# 3468               NaN
# 3469               NaN
# 3470               NaN
#
# [3471 rows x 22 columns]

# %%
#get within package
df_package = pd.DataFrame()
i = 0
while i < df_anti.shape[0]:
    df_temp = pd.DataFrame(df_anti.packaging[i])
    df_temp.insert(0,"generic_name", df_anti.generic_name[i])
    df_temp.insert(1,"labeler_name", df_anti.labeler_name[i])
    df_temp.insert(2,"brand_name", df_anti.brand_name[i])
    df_package = pd.concat([df_package, df_temp]).drop_duplicates(subset=['package_ndc']).reset_index(drop=True)
    i+=1
df_package
# Out:
#                                            generic_name  \
# 0     5-hydroxy tryptophan,dl - alfalfa - avena sati...
# 1                           AMITRIPTYLINE HYDROCHLORIDE
# 2                           Amitriptyline Hydrochloride
# 3                           Amitriptyline Hydrochloride
# 4                           Amitriptyline Hydrochloride
# ...                                                 ...
# 8029                                       vortioxetine
# 8030                          VORTIOXETINE HYDROBROMIDE
# 8031                                       Vortioxetine
# 8032                                       Vortioxetine
# 8033                                       Vortioxetine
#
#                                            labeler_name  \
# 0                                              Guna spa
# 1     Professional Compounding Centers of America db...
# 2                                  Bryant Ranch Prepack
# 3                                  Bryant Ranch Prepack
# 4                                  Bryant Ranch Prepack
# ...                                                 ...
# 8029               Takeda Pharmaceuticals America, Inc.
# 8030            APICORE PHARMACEUTICALS PRIVATE LIMITED
# 8031                                        Takeda GmbH
# 8032                                        Takeda GmbH
# 8033                                        Takeda GmbH
#
#                        brand_name   package_ndc  \
# 0                       GUNA-MOOD  17089-265-18
# 1                             NaN  51927-1603-0
# 2     Amitriptyline Hydrochloride  63629-3597-1
# 3     Amitriptyline Hydrochloride  63629-3597-2
# 4     Amitriptyline Hydrochloride  63629-3597-3
# ...                           ...           ...
# 8029                   Trintellix  64764-730-90
# 8030                          NaN  42973-236-00
# 8031                          NaN  47234-4120-1
# 8032                          NaN  47234-4105-1
# 8033                          NaN  47234-4110-1
#
#                                             description marketing_start_date  \
# 0     1 BOTTLE, DROPPER in 1 BOX (17089-265-18)  > 3...             20181221
# 1                    1 kg in 1 CONTAINER (51927-1603-0)            20-JUN-13
# 2     30 TABLET, FILM COATED in 1 BOTTLE (63629-3597-1)             20220330
# 3     100 TABLET, FILM COATED in 1 BOTTLE (63629-359...             20220330
# 4     28 TABLET, FILM COATED in 1 BOTTLE (63629-3597-3)             20220330
# ...                                                 ...                  ...
# 8029  90 TABLET, FILM COATED in 1 BOTTLE (64764-730-90)             20131002
# 8030                     50 kg in 1 DRUM (42973-236-00)            01-AUG-17
# 8031  129450 TABLET, FILM COATED in 1 DRUM (47234-41...            02-OCT-13
# 8032  129450 TABLET, FILM COATED in 1 DRUM (47234-41...            02-OCT-13
# 8033  129450 TABLET, FILM COATED in 1 DRUM (47234-41...            02-OCT-13
#
#      sample marketing_end_date
# 0     False                NaN
# 1       NaN                NaN
# 2     False                NaN
# 3     False                NaN
# 4     False                NaN
# ...     ...                ...
# 8029  False                NaN
# 8030    NaN                NaN
# 8031    NaN                NaN
# 8032    NaN                NaN
# 8033    NaN                NaN
#
# [8034 rows x 8 columns]

# %%
#Change to NDC11
for ele in df_package.package_ndc:
    s = ele.split("-")
    S = []
    for i, L in enumerate([5,4,2]):
        if len(s[i]) < L:
            S.append('0'*(L-len(s[i])) + s[i])
        else:
            S.append(s[i])
    ndc11 = ''.join(S)
    df_package.replace(ele,ndc11, inplace=True)
df_package
# Out:
#                                            generic_name  \
# 0     5-hydroxy tryptophan,dl - alfalfa - avena sati...
# 1                           AMITRIPTYLINE HYDROCHLORIDE
# 2                           Amitriptyline Hydrochloride
# 3                           Amitriptyline Hydrochloride
# 4                           Amitriptyline Hydrochloride
# ...                                                 ...
# 8029                                       vortioxetine
# 8030                          VORTIOXETINE HYDROBROMIDE
# 8031                                       Vortioxetine
# 8032                                       Vortioxetine
# 8033                                       Vortioxetine
#
#                                            labeler_name  \
# 0                                              Guna spa
# 1     Professional Compounding Centers of America db...
# 2                                  Bryant Ranch Prepack
# 3                                  Bryant Ranch Prepack
# 4                                  Bryant Ranch Prepack
# ...                                                 ...
# 8029               Takeda Pharmaceuticals America, Inc.
# 8030            APICORE PHARMACEUTICALS PRIVATE LIMITED
# 8031                                        Takeda GmbH
# 8032                                        Takeda GmbH
# 8033                                        Takeda GmbH
#
#                        brand_name  package_ndc  \
# 0                       GUNA-MOOD  17089026518
# 1                             NaN  51927160300
# 2     Amitriptyline Hydrochloride  63629359701
# 3     Amitriptyline Hydrochloride  63629359702
# 4     Amitriptyline Hydrochloride  63629359703
# ...                           ...          ...
# 8029                   Trintellix  64764073090
# 8030                          NaN  42973023600
# 8031                          NaN  47234412001
# 8032                          NaN  47234410501
# 8033                          NaN  47234411001
#
#                                             description marketing_start_date  \
# 0     1 BOTTLE, DROPPER in 1 BOX (17089-265-18)  > 3...             20181221
# 1                    1 kg in 1 CONTAINER (51927-1603-0)            20-JUN-13
# 2     30 TABLET, FILM COATED in 1 BOTTLE (63629-3597-1)             20220330
# 3     100 TABLET, FILM COATED in 1 BOTTLE (63629-359...             20220330
# 4     28 TABLET, FILM COATED in 1 BOTTLE (63629-3597-3)             20220330
# ...                                                 ...                  ...
# 8029  90 TABLET, FILM COATED in 1 BOTTLE (64764-730-90)             20131002
# 8030                     50 kg in 1 DRUM (42973-236-00)            01-AUG-17
# 8031  129450 TABLET, FILM COATED in 1 DRUM (47234-41...            02-OCT-13
# 8032  129450 TABLET, FILM COATED in 1 DRUM (47234-41...            02-OCT-13
# 8033  129450 TABLET, FILM COATED in 1 DRUM (47234-41...            02-OCT-13
#
#      sample marketing_end_date
# 0     False                NaN
# 1       NaN                NaN
# 2     False                NaN
# 3     False                NaN
# 4     False                NaN
# ...     ...                ...
# 8029  False                NaN
# 8030    NaN                NaN
# 8031    NaN                NaN
# 8032    NaN                NaN
# 8033    NaN                NaN
#
# [8034 rows x 8 columns]

# %%
df_package.to_excel("ndc_antidepressants.xlsx", index=False)

# %%
#com
df_hedis = pd.read_excel("HEDIS MY 2021 Medication List Directory 2021-03-31.xlsx", sheet_name="Medication Lists to Codes", dtype='object')
df_hedis
# Out:
#                 Medication List Name                Medication List OID  \
# 0                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 1                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 2                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 3                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# 4                  5 ARI Medications  2.16.840.1.113883.3.464.1004.1739
# ...                              ...                                ...
# 224861  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224862  Ziprasidone Oral Medications  2.16.840.1.113883.3.464.1004.1939
# 224863                           NaN                                NaN
# 224864                           NaN                                NaN
# 224865                           NaN                                NaN
#
#        Medication List Version         Code            Generic Product Name  \
# 0                   2021-03-31  00006007107    finasteride 1 MG Oral Tablet
# 1                   2021-03-31  00006007131    finasteride 1 MG Oral Tablet
# 2                   2021-03-31  00006007154    finasteride 1 MG Oral Tablet
# 3                   2021-03-31  00006007231    finasteride 5 MG Oral Tablet
# 4                   2021-03-31  00006007258    finasteride 5 MG Oral Tablet
# ...                        ...          ...                             ...
# 224861              2021-03-31       313778  ziprasidone 80 MG Oral Capsule
# 224862              2021-03-31       314286  ziprasidone 20 MG Oral Capsule
# 224863                     NaN          NaN                             NaN
# 224864                                  NaN                             NaN
# 224865                                  NaN                             NaN
#
#                                      Brand Name Route Package Size Unit  \
# 0       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 1       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 2       finasteride 1 MG Oral Tablet [Propecia]  oral          NaN  NaN
# 3        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# 4        finasteride 5 MG Oral Tablet [Proscar]  oral          NaN  NaN
# ...                                         ...   ...          ...  ...
# 224861                                      NaN  oral          NaN  NaN
# 224862                                      NaN  oral          NaN  NaN
# 224863                                      NaN   NaN          NaN  NaN
# 224864                                      NaN   NaN          NaN  NaN
# 224865                                      NaN   NaN          NaN  NaN
#
#        Code System         Code System OID Code System Version Drug Class
# 0              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4              NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...            ...                     ...                 ...        ...
# 224861      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224862      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 224863         NaN                     NaN                 NaN        NaN
# 224864         NaN                     NaN                 NaN        NaN
# 224865         NaN                     NaN                 NaN        NaN
#
# [224866 rows x 13 columns]

# %%
df_hedis = df_hedis.loc[df_hedis['Medication List Name']=="Antidepressant Medications"]

# %%
df_hedis.reset_index(drop=True)
# Out:
#              Medication List Name                Medication List OID  \
# 0      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4      Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                           ...                                ...
# 12735  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12736  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12737  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12738  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 12739  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#       Medication List Version         Code  \
# 0                  2021-03-31  00002300475
# 1                  2021-03-31  00002323030
# 2                  2021-03-31  00002323101
# 3                  2021-03-31  00002323130
# 4                  2021-03-31  00002323133
# ...                       ...          ...
# 12735              2021-03-31      2200177
# 12736              2021-03-31      2200178
# 12737              2021-03-31      2200180
# 12738              2021-03-31      2200181
# 12739              2021-03-31      2200183
#
#                                     Generic Product Name  \
# 0          fluoxetine 90 MG Delayed Release Oral Capsule
# 1        fluoxetine 25 MG / olanzapine 3 MG Oral Capsule
# 2        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 4        fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# ...                                                  ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 12736  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 12738  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                               Brand Name Route Package Size  \
# 0      fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1      fluoxetine 25 MG / olanzapine 3 MG Oral Capsul...  oral          NaN
# 2      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 4      fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                  ...   ...          ...
# 12735  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 12736                                                NaN  oral          NaN
# 12737  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 12738                                                NaN  oral          NaN
# 12739  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#       Unit Code System         Code System OID Code System Version Drug Class
# 0      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4      NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...    ...         ...                     ...                 ...        ...
# 12735  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12736  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12737  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12738  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 12739  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [12740 rows x 13 columns]

# %%
#Identify new drugs found
same_drug_count = 0
new_drug_count = 0
drug_not_found_count = 0
same_drug = pd.DataFrame()
new_drug = pd.DataFrame()
for code in df_package['package_ndc']:
    if df_hedis.isin([str(code)]).any().any() == True:
        same_drug_count += 1
        same_drug = pd.concat([same_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
    else:
        new_drug_count += 1
        new_drug = pd.concat([new_drug, df_package.loc[df_package['package_ndc']==code]]).reset_index(drop=True)
print('Same drug count: ', same_drug_count)
print('New drug count: ', new_drug_count)
# Out:
# Same drug count:  5452
# New drug count:  2582

# %%
absent_drugs = pd.DataFrame()
count = 0
#for every code from the combind excel list
for code in df_hedis['Code']:
    if df_package.isin([str(code)]).any().any() == True:
        count+=1
    else:
        absent_drugs = pd.concat([absent_drugs, df_hedis.loc[df_hedis['Code']==code]]).reset_index(drop=True)
print('Count: ', count)
absent_drugs
# Out:
# Count:  5452
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7283  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7284  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7285  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7286  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7287  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7283              2021-03-31      2200177
# 7284              2021-03-31      2200178
# 7285              2021-03-31      2200180
# 7286              2021-03-31      2200181
# 7287              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7283  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7284  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7285  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7286  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7287  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7283  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7284                                                NaN  oral          NaN
# 7285  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7286                                                NaN  oral          NaN
# 7287  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7283  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7284  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7285  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7286  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7287  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7288 rows x 13 columns]

# %%
#export
same_drug.to_excel("Same_Antidepressants_Medications.xlsx", index=False)
new_drug.to_excel("New_Antidepressants_Added.xlsx", index=False)
absent_drugs.to_excel("Absent_Antidepressants.xlsx", index=False)

# %%
absent_drugs
# Out:
#             Medication List Name                Medication List OID  \
# 0     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 1     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 2     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 3     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 4     Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# ...                          ...                                ...
# 7283  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7284  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7285  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7286  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
# 7287  Antidepressant Medications  2.16.840.1.113883.3.464.1004.1503
#
#      Medication List Version         Code  \
# 0                 2021-03-31  00002300475
# 1                 2021-03-31  00002323101
# 2                 2021-03-31  00002323133
# 3                 2021-03-31  00002323230
# 4                 2021-03-31  00002323301
# ...                      ...          ...
# 7283              2021-03-31      2200177
# 7284              2021-03-31      2200178
# 7285              2021-03-31      2200180
# 7286              2021-03-31      2200181
# 7287              2021-03-31      2200183
#
#                                    Generic Product Name  \
# 0         fluoxetine 90 MG Delayed Release Oral Capsule
# 1       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 2       fluoxetine 25 MG / olanzapine 6 MG Oral Capsule
# 3      fluoxetine 25 MG / olanzapine 12 MG Oral Capsule
# 4       fluoxetine 50 MG / olanzapine 6 MG Oral Capsule
# ...                                                 ...
# 7283  Sprinkle duloxetine 30 MG Delayed Release Oral...
# 7284  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7285  Sprinkle duloxetine 40 MG Delayed Release Oral...
# 7286  Sprinkle duloxetine 60 MG Delayed Release Oral...
# 7287  Sprinkle duloxetine 60 MG Delayed Release Oral...
#
#                                              Brand Name Route Package Size  \
# 0     fluoxetine 90 MG Delayed Release Oral Capsule ...  oral          NaN
# 1     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 2     fluoxetine 25 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# 3     fluoxetine 25 MG / olanzapine 12 MG Oral Capsu...  oral          NaN
# 4     fluoxetine 50 MG / olanzapine 6 MG Oral Capsul...  oral          NaN
# ...                                                 ...   ...          ...
# 7283  Sprinkle duloxetine 30 MG Delayed Release Oral...  oral          NaN
# 7284                                                NaN  oral          NaN
# 7285  Sprinkle duloxetine 40 MG Delayed Release Oral...  oral          NaN
# 7286                                                NaN  oral          NaN
# 7287  Sprinkle duloxetine 60 MG Delayed Release Oral...  oral          NaN
#
#      Unit Code System         Code System OID Code System Version Drug Class
# 0     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 1     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 2     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 3     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# 4     NaN         NDC  2.16.840.1.113883.6.69     2021.01.04.20AB        NaN
# ...   ...         ...                     ...                 ...        ...
# 7283  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7284  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7285  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7286  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
# 7287  NaN      RxNorm  2.16.840.1.113883.6.88     2021.01.04.20AB        NaN
#
# [7288 rows x 13 columns]
