# %%
import pandas as pd
base_url = "https://rxnav.nlm.nih.gov/REST/rxcui/"
base_url_2 = "https://rxnav.nlm.nih.gov/REST/"

# %%
df = pd.read_excel("Absent_Opioid.xlsx",dtype="object")

# %%
df
# Out:
#                NDC  NDC_Numeric                        PRODNME  \
# 0      00002035102      2035102                  DARVOCET-N 50
# 1      00002035103      2035103                  DARVOCET-N 50
# 2      00002035133      2035133                  DARVOCET-N 50
# 3      00002035302      2035302                       DARVON-N
# 4      00002035303      2035303                       DARVON-N
# ...            ...          ...                            ...
# 13435  99999700061  99999700061         PROPOXYPHENE NAPSYLATE
# 13436  99999875926  99999875926             APAP W/HYDROCODONE
# 13437  99999900000  99999900000        ACETAMINOPHEN W/CODEINE
# 13438  99999987600  99999987600  APAP W/PROPOXYPHENE NAPSYLATE
# 13439  99999987700  99999987700  APAP W/PROPOXYPHENE NAPSYLATE
#
#                                      GENNME Master_Form   Class  \
# 0      Acetaminophen/propoxyphene Napsylate      Tablet  Opioid
# 1      Acetaminophen/propoxyphene Napsylate      Tablet  Opioid
# 2      Acetaminophen/propoxyphene Napsylate      Tablet  Opioid
# 3                    Propoxyphene Napsylate      Tablet  Opioid
# 4                    Propoxyphene Napsylate      Tablet  Opioid
# ...                                     ...         ...     ...
# 13435                Propoxyphene Napsylate      Tablet  Opioid
# 13436  Acetaminophen/hydrocodone Bitartrate     Capsule  Opioid
# 13437       Acetaminophen/codeine Phosphate      Tablet  Opioid
# 13438  Acetaminophen/propoxyphene Napsylate      Tablet  Opioid
# 13439  Acetaminophen/propoxyphene Napsylate      Tablet  Opioid
#
#                  Drug LongShortActing DEAClassCode Strength_Per_Unit UOM  \
# 0        Propoxyphene              SA            4                50  MG
# 1        Propoxyphene              SA            4                50  MG
# 2        Propoxyphene              SA            4                50  MG
# 3        Propoxyphene              SA            4               100  MG
# 4        Propoxyphene              SA            4               100  MG
# ...               ...             ...          ...               ...  ..
# 13435    Propoxyphene              SA            4               100  MG
# 13436  Hydrocodone SA              SA            2                 5  MG
# 13437         Codeine              SA            3                30  MG
# 13438    Propoxyphene              SA            4                50  MG
# 13439    Propoxyphene              SA            4               100  MG
#
#       MME_Conversion_Factor
# 0                      0.23
# 1                      0.23
# 2                      0.23
# 3                      0.23
# 4                      0.23
# ...                     ...
# 13435                  0.23
# 13436                     1
# 13437                  0.15
# 13438                  0.23
# 13439                  0.23
#
# [13440 rows x 12 columns]

# %%
#find the status of the not found drugs
df_status = pd.DataFrame()
index = 0
for code in df['NDC']:
    getndcStatus = 'ndcstatus.json?ndc={}&history=0&altpkg=1'.format(code)
    df_type = pd.read_json(base_url_2+getndcStatus)
    df_type = df_type.transpose()
    df_type['ndc'] = code
    df_status = pd.concat([df_status, df_type]).drop_duplicates(subset=['ndc']).reset_index(drop=True)
df_status
# Out:
#       active altNdc comment  \
# 0         NO      N    None
# 1         NO      N    None
# 2         NO      N    None
# 3         NO      N    None
# 4         NO      N    None
# ...      ...    ...     ...
# 13435    YES      Y    None
# 13436             N    None
# 13437     NO      Y    None
# 13438             N    None
# 13439             N    None
#
#                                              conceptName conceptStatus  \
# 0      Acetaminophen 325 MG / propoxyphene napsylate ...      OBSOLETE
# 1      acetaminophen 325 MG / propoxyphene napsylate ...        ACTIVE
# 2      acetaminophen 325 MG / propoxyphene napsylate ...        ACTIVE
# 3      propoxyphene napsylate 100 MG Oral Tablet [Dar...      OBSOLETE
# 4      propoxyphene napsylate 100 MG Oral Tablet [Dar...      OBSOLETE
# ...                                                  ...           ...
# 13435                 MED DOSE CUP GRAD METRIC ONLY 30ML    NOTCURRENT
# 13436
# 13437                                   ALKALOL SOLUTION    NOTCURRENT
# 13438
# 13439
#
#              ndc11                                         ndcHistory  \
# 0      00002035102  [{'activeRxcui': '', 'originalRxcui': '849694'...
# 1      00002035103  [{'activeRxcui': '849295', 'originalRxcui': '8...
# 2      00002035133  [{'activeRxcui': '849295', 'originalRxcui': '8...
# 3      00002035302  [{'activeRxcui': '', 'originalRxcui': '827750'...
# 4      00002035303  [{'activeRxcui': '', 'originalRxcui': '827750'...
# ...            ...                                                ...
# 13435  99999700000                                                NaN
# 13436  99999875926                                                NaN
# 13437  99999900001                                                NaN
# 13438  99999987600                                                NaN
# 13439  99999987700                                                NaN
#
#          rxcui rxnormNdc                                         sourceList  \
# 0       849694       YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...
# 1       849295       YES                {'sourceName': ['RXNORM', 'VANDF']}
# 2       849295       YES                {'sourceName': ['RXNORM', 'VANDF']}
# 3       827750       YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...
# 4       827750       YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...
# ...        ...       ...                                                ...
# 13435  2166917        NO                          {'sourceName': ['VANDF']}
# 13436                                                                    {}
# 13437   654231        NO                                                 {}
# 13438                                                                    {}
# 13439                                                                    {}
#
#          status          ndc  \
# 0      OBSOLETE  00002035102
# 1      OBSOLETE  00002035103
# 2      OBSOLETE  00002035133
# 3      OBSOLETE  00002035302
# 4      OBSOLETE  00002035303
# ...         ...          ...
# 13435     ALIEN  99999700061
# 13436   UNKNOWN  99999875926
# 13437     ALIEN  99999900000
# 13438   UNKNOWN  99999987600
# 13439   UNKNOWN  99999987700
#
#                                         ndcSourceMapping
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13435  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 13436                                                NaN
# 13437                                                NaN
# 13438                                                NaN
# 13439                                                NaN
#
# [13440 rows x 13 columns]

# %%
df_status.to_excel("ndcstatus.xlsx",index=False)

# %%
df_status.altNdc.replace("N", "NO", inplace=True)
df_status.altNdc.replace("Y", "YES", inplace=True)

# %%
df_obsolete = df_status.loc[df_status['active']== 'NO'].reset_index(drop=True)

# %%
df_obsolete
# Out:
#       active altNdc comment  \
# 0         NO     NO    None
# 1         NO     NO    None
# 2         NO     NO    None
# 3         NO     NO    None
# 4         NO     NO    None
# ...      ...    ...     ...
# 11272     NO    YES    None
# 11273     NO    YES    None
# 11274     NO    YES    None
# 11275     NO    YES    None
# 11276     NO    YES    None
#
#                                              conceptName conceptStatus  \
# 0      Acetaminophen 325 MG / propoxyphene napsylate ...      OBSOLETE
# 1      acetaminophen 325 MG / propoxyphene napsylate ...        ACTIVE
# 2      acetaminophen 325 MG / propoxyphene napsylate ...        ACTIVE
# 3      propoxyphene napsylate 100 MG Oral Tablet [Dar...      OBSOLETE
# 4      propoxyphene napsylate 100 MG Oral Tablet [Dar...      OBSOLETE
# ...                                                  ...           ...
# 11272            TUBING,TRACH SUCT 1/4INX6FT C#BQ0036280    NOTCURRENT
# 11273          LEG BAG STRAP,UPPER,X-LARGE,UROCARE #6346    NOTCURRENT
# 11274                     CAP,TUBING 3/4IN NU-HOPE #9062    NOTCURRENT
# 11275                COLLY-SEEL DISC 4 1/2IN MASON #224Y    NOTCURRENT
# 11276                                   ALKALOL SOLUTION    NOTCURRENT
#
#              ndc11                                         ndcHistory  \
# 0      00002035102  [{'activeRxcui': '', 'originalRxcui': '849694'...
# 1      00002035103  [{'activeRxcui': '849295', 'originalRxcui': '8...
# 2      00002035133  [{'activeRxcui': '849295', 'originalRxcui': '8...
# 3      00002035302  [{'activeRxcui': '', 'originalRxcui': '827750'...
# 4      00002035303  [{'activeRxcui': '', 'originalRxcui': '827750'...
# ...            ...                                                ...
# 11272  99999003628                                                NaN
# 11273  99999006346                                                NaN
# 11274  99999009062                                                NaN
# 11275  99999022410                                                NaN
# 11276  99999900001                                                NaN
#
#          rxcui rxnormNdc                                         sourceList  \
# 0       849694       YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...
# 1       849295       YES                {'sourceName': ['RXNORM', 'VANDF']}
# 2       849295       YES                {'sourceName': ['RXNORM', 'VANDF']}
# 3       827750       YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...
# 4       827750       YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...
# ...        ...       ...                                                ...
# 11272  1291361        NO                                                 {}
# 11273   489449        NO                          {'sourceName': ['VANDF']}
# 11274  1243416        NO                          {'sourceName': ['VANDF']}
# 11275   488738        NO                          {'sourceName': ['VANDF']}
# 11276   654231        NO                                                 {}
#
#          status          ndc  \
# 0      OBSOLETE  00002035102
# 1      OBSOLETE  00002035103
# 2      OBSOLETE  00002035133
# 3      OBSOLETE  00002035302
# 4      OBSOLETE  00002035303
# ...         ...          ...
# 11272     ALIEN  99999003636
# 11273     ALIEN  99999006395
# 11274     ALIEN  99999009090
# 11275     ALIEN  99999022405
# 11276     ALIEN  99999900000
#
#                                         ndcSourceMapping
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11272                                                NaN
# 11273  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 11274  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 11275  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 11276                                                NaN
#
# [11277 rows x 13 columns]

# %%
df_active = df_status.loc[df_status['active']== 'YES'].reset_index(drop=True)

# %%
df_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0       YES     NO    None  acetaminophen 325 MG / hydrocodone bitartrate ...
# 1       YES     NO    None  aspirin 325 MG / butalbital 50 MG / caffeine 4...
# 2       YES     NO    None  morphine sulfate 20 MG Extended Release Oral C...
# 3       YES     NO    None  morphine sulfate 30 MG Extended Release Oral C...
# 4       YES     NO    None  morphine sulfate 40 MG Extended Release Oral C...
# ...     ...    ...     ...                                                ...
# 1893    YES     NO    None               buprenorphine 8 MG Sublingual Tablet
# 1894    YES     NO    None               buprenorphine 8 MG Sublingual Tablet
# 1895    YES     NO    None                     WOUND CARE KIT,DEROYAL #47-758
# 1896    YES    YES    None                 MED DOSE CUP GRAD METRIC ONLY 30ML
# 1897    YES    YES    None                 MED DOSE CUP GRAD METRIC ONLY 30ML
#
#      conceptStatus        ndc11  \
# 0           ACTIVE  00023600201
# 1           ACTIVE  00023601001
# 2           ACTIVE  00023601260
# 3           ACTIVE  00023601360
# 4           ACTIVE  00023601460
# ...            ...          ...
# 1893        ACTIVE  76519117004
# 1894        ACTIVE  76519117005
# 1895    NOTCURRENT  99999000000
# 1896    NOTCURRENT  99999700000
# 1897    NOTCURRENT  99999700000
#
#                                              ndcHistory    rxcui rxnormNdc  \
# 0     [{'activeRxcui': '857004', 'originalRxcui': '8...   857004       YES
# 1     [{'activeRxcui': '994277', 'originalRxcui': '9...   994277       YES
# 2     [{'activeRxcui': '892598', 'originalRxcui': '8...   892598       YES
# 3     [{'activeRxcui': '892658', 'originalRxcui': '8...   892658       YES
# 4     [{'activeRxcui': '1303738', 'originalRxcui': '...  1303738       YES
# ...                                                 ...      ...       ...
# 1893  [{'activeRxcui': '351265', 'originalRxcui': '3...   351265       YES
# 1894  [{'activeRxcui': '351265', 'originalRxcui': '3...   351265       YES
# 1895                                                NaN  1095572        NO
# 1896                                                NaN  2166917        NO
# 1897                                                NaN  2166917        NO
#
#                                              sourceList  status          ndc  \
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023600201
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601001
# 2     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601260
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601360
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601460
# ...                                                 ...     ...          ...
# 1893        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519117004
# 1894        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519117005
# 1895                          {'sourceName': ['VANDF']}   ALIEN  99999000000
# 1896                          {'sourceName': ['VANDF']}   ALIEN  99999700060
# 1897                          {'sourceName': ['VANDF']}   ALIEN  99999700061
#
#                                        ndcSourceMapping
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1893                                                NaN
# 1894                                                NaN
# 1895  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 1896  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 1897  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
#
# [1898 rows x 13 columns]

# %%
df_not_active = df_status.loc[df_status['active']!= 'YES'].reset_index(drop=True)

# %%
df_not_active
# Out:
#       active altNdc comment  \
# 0         NO     NO    None
# 1         NO     NO    None
# 2         NO     NO    None
# 3         NO     NO    None
# 4         NO     NO    None
# ...      ...    ...     ...
# 11537            NO    None
# 11538            NO    None
# 11539     NO    YES    None
# 11540            NO    None
# 11541            NO    None
#
#                                              conceptName conceptStatus  \
# 0      Acetaminophen 325 MG / propoxyphene napsylate ...      OBSOLETE
# 1      acetaminophen 325 MG / propoxyphene napsylate ...        ACTIVE
# 2      acetaminophen 325 MG / propoxyphene napsylate ...        ACTIVE
# 3      propoxyphene napsylate 100 MG Oral Tablet [Dar...      OBSOLETE
# 4      propoxyphene napsylate 100 MG Oral Tablet [Dar...      OBSOLETE
# ...                                                  ...           ...
# 11537
# 11538
# 11539                                   ALKALOL SOLUTION    NOTCURRENT
# 11540
# 11541
#
#              ndc11                                         ndcHistory   rxcui  \
# 0      00002035102  [{'activeRxcui': '', 'originalRxcui': '849694'...  849694
# 1      00002035103  [{'activeRxcui': '849295', 'originalRxcui': '8...  849295
# 2      00002035133  [{'activeRxcui': '849295', 'originalRxcui': '8...  849295
# 3      00002035302  [{'activeRxcui': '', 'originalRxcui': '827750'...  827750
# 4      00002035303  [{'activeRxcui': '', 'originalRxcui': '827750'...  827750
# ...            ...                                                ...     ...
# 11537  99999658796                                                NaN
# 11538  99999875926                                                NaN
# 11539  99999900001                                                NaN  654231
# 11540  99999987600                                                NaN
# 11541  99999987700                                                NaN
#
#       rxnormNdc                                         sourceList    status  \
# 0           YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE
# 1           YES                {'sourceName': ['RXNORM', 'VANDF']}  OBSOLETE
# 2           YES                {'sourceName': ['RXNORM', 'VANDF']}  OBSOLETE
# 3           YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE
# 4           YES  {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHFDA',...  OBSOLETE
# ...         ...                                                ...       ...
# 11537                                                           {}   UNKNOWN
# 11538                                                           {}   UNKNOWN
# 11539        NO                                                 {}     ALIEN
# 11540                                                           {}   UNKNOWN
# 11541                                                           {}   UNKNOWN
#
#                ndc ndcSourceMapping
# 0      00002035102              NaN
# 1      00002035103              NaN
# 2      00002035133              NaN
# 3      00002035302              NaN
# 4      00002035303              NaN
# ...            ...              ...
# 11537  99999658796              NaN
# 11538  99999875926              NaN
# 11539  99999900000              NaN
# 11540  99999987600              NaN
# 11541  99999987700              NaN
#
# [11542 rows x 13 columns]

# %%
df_active.to_excel("active.xlsx",index=False)
df_not_active.to_excel("NOT_active.xlsx",index=False)

# %%
df_not_active_blank = df_not_active.loc[df_not_active['active']!= 'NO'].reset_index(drop=True)

# %%
df_not_active_blank
# Out:
#     active altNdc comment conceptName conceptStatus        ndc11 ndcHistory  \
# 0              NO    None                            00002311202        NaN
# 1              NO    None                            00002311203        NaN
# 2              NO    None                            00005312323        NaN
# 3              NO    None                            00005312331        NaN
# 4              NO    None                            00015571160        NaN
# ..     ...    ...     ...         ...           ...          ...        ...
# 260            NO    None                            99999658726        NaN
# 261            NO    None                            99999658796        NaN
# 262            NO    None                            99999875926        NaN
# 263            NO    None                            99999987600        NaN
# 264            NO    None                            99999987700        NaN
#
#     rxcui rxnormNdc sourceList   status          ndc ndcSourceMapping
# 0                           {}  UNKNOWN  00002311202              NaN
# 1                           {}  UNKNOWN  00002311203              NaN
# 2                           {}  UNKNOWN  00005312323              NaN
# 3                           {}  UNKNOWN  00005312331              NaN
# 4                           {}  UNKNOWN  00015571160              NaN
# ..    ...       ...        ...      ...          ...              ...
# 260                         {}  UNKNOWN  99999658726              NaN
# 261                         {}  UNKNOWN  99999658796              NaN
# 262                         {}  UNKNOWN  99999875926              NaN
# 263                         {}  UNKNOWN  99999987600              NaN
# 264                         {}  UNKNOWN  99999987700              NaN
#
# [265 rows x 13 columns]

# %%
df_active = pd.read_excel("active.xlsx", dtype="object")

# %%
df_active
# Out:
#      active altNdc comment                                        conceptName  \
# 0       YES     NO     NaN  acetaminophen 325 MG / hydrocodone bitartrate ...
# 1       YES     NO     NaN  aspirin 325 MG / butalbital 50 MG / caffeine 4...
# 2       YES     NO     NaN  morphine sulfate 20 MG Extended Release Oral C...
# 3       YES     NO     NaN  morphine sulfate 30 MG Extended Release Oral C...
# 4       YES     NO     NaN  morphine sulfate 40 MG Extended Release Oral C...
# ...     ...    ...     ...                                                ...
# 1893    YES     NO     NaN               buprenorphine 8 MG Sublingual Tablet
# 1894    YES     NO     NaN               buprenorphine 8 MG Sublingual Tablet
# 1895    YES     NO     NaN                     WOUND CARE KIT,DEROYAL #47-758
# 1896    YES    YES     NaN                 MED DOSE CUP GRAD METRIC ONLY 30ML
# 1897    YES    YES     NaN                 MED DOSE CUP GRAD METRIC ONLY 30ML
#
#      conceptStatus        ndc11  \
# 0           ACTIVE  00023600201
# 1           ACTIVE  00023601001
# 2           ACTIVE  00023601260
# 3           ACTIVE  00023601360
# 4           ACTIVE  00023601460
# ...            ...          ...
# 1893        ACTIVE  76519117004
# 1894        ACTIVE  76519117005
# 1895    NOTCURRENT  99999000000
# 1896    NOTCURRENT  99999700000
# 1897    NOTCURRENT  99999700000
#
#                                              ndcHistory    rxcui rxnormNdc  \
# 0     [{'activeRxcui': '857004', 'originalRxcui': '8...   857004       YES
# 1     [{'activeRxcui': '994277', 'originalRxcui': '9...   994277       YES
# 2     [{'activeRxcui': '892598', 'originalRxcui': '8...   892598       YES
# 3     [{'activeRxcui': '892658', 'originalRxcui': '8...   892658       YES
# 4     [{'activeRxcui': '1303738', 'originalRxcui': '...  1303738       YES
# ...                                                 ...      ...       ...
# 1893  [{'activeRxcui': '351265', 'originalRxcui': '3...   351265       YES
# 1894  [{'activeRxcui': '351265', 'originalRxcui': '3...   351265       YES
# 1895                                                NaN  1095572        NO
# 1896                                                NaN  2166917        NO
# 1897                                                NaN  2166917        NO
#
#                                              sourceList  status          ndc  \
# 0     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023600201
# 1     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601001
# 2     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601260
# 3     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601360
# 4     {'sourceName': ['GS', 'MMSL', 'MMX', 'MTHSPL',...  ACTIVE  00023601460
# ...                                                 ...     ...          ...
# 1893        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519117004
# 1894        {'sourceName': ['MMX', 'MTHSPL', 'RXNORM']}  ACTIVE  76519117005
# 1895                          {'sourceName': ['VANDF']}   ALIEN  99999000000
# 1896                          {'sourceName': ['VANDF']}   ALIEN  99999700060
# 1897                          {'sourceName': ['VANDF']}   ALIEN  99999700061
#
#                                        ndcSourceMapping
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1893                                                NaN
# 1894                                                NaN
# 1895  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 1896  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
# 1897  [{'ndcSource': 'VANDF', 'ndcActive': 'YES', 'n...
#
# [1898 rows x 13 columns]

# %%
i = 0
df_search=pd.DataFrame()
for code in df_active["ndc"]:
    ndc = code
    if ndc[0] == "0":
        ndc=ndc[1:]
        #4-4-2
        ndc = ndc[:4]+'-'+ ndc[4:8]+'-'+ndc[8:]
    elif ndc[9]!="0":
        #5-3-2
        ndc = ndc[:5]+'-'+ ndc[6:9]+'-'+ndc[9:]
    elif ndc[5]=="0":
        #identify whether it is 5-4 or 5-3
        #5-4
        ndc4=ndc[:5]+"-"+ndc[5:9]
        #5-3
        ndc3=ndc[:5]+'-'+ ndc[6:9]
        try:
            flag4 = pd.read_json("https://api.fda.gov/drug/ndc.json?search=product_ndc:{}".format(ndc4), orient='values', typ='series', convert_dates=False)
        except:
            flag4=pd.DataFrame()
        try:
            flag3 = pd.read_json("https://api.fda.gov/drug/ndc.json?search=product_ndc:{}".format(ndc3), orient='values', typ='series', convert_dates=False)
        except:
            flag3=pd.DataFrame()
        if (flag3.empty is True and flag4.empty is True):
            #if the product does not exist the ndc will be set to 0 because the package will not exist
            ndc = "0"
        elif flag3.empty == False:
            #5-3-2
            ndc = ndc[:5]+'-'+ ndc[6:9]+'-'+ndc[9:]
        elif flag4.empty== False:
            #5-4-1
            ndc=ndc[:5]+"-"+ndc[5:9]+'-'+ndc[10:]
        else:
            print("Duplicate Flag")
    elif ndc[9]=="0":
        ndc=ndc[:5]+"-"+ndc[5:9]+'-'+ndc[10:]
    else:
        print("ndc error: "+ndc)
    df_A = pd.DataFrame()
    try:
        df_A = pd.read_json("https://api.fda.gov/drug/ndc.json?search=packaging.package_ndc:{}".format(ndc), orient='values', typ='series', convert_dates=False)
        df_A = pd.DataFrame(df_A.results)
    except:
        i+=1
    df_search = pd.concat([df_search,df_A]).reset_index(drop=True)

# %%
pd.read_json("https://api.fda.gov/drug/ndc.json?search=packaging.package_ndc:{}".format("71335-1260-1"), orient='values', typ='series', convert_dates=False)
# Out:
# meta       {'disclaimer': 'Do not rely on openFDA to make...
# results    [{'product_ndc': '71335-1260', 'generic_name':...
# dtype: object

# %%
df_search
# Out:
# Empty DataFrame
# Columns: []
# Index: []
