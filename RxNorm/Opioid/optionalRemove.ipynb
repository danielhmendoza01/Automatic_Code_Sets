# %%
import pandas as pd
df_opioid = pd.read_excel("/Users/hm/Documents/New Code/Automatic_Code_Sets/RxNorm/Appendices/Appendix1.xlsx")

# %%
keywords = ['Lotion', 'Ointment', 'Spray', 'Cream']
pattern = '|'.join(keywords)
df_opioid = df_opioid[df_opioid['name'].str.contains(pattern, case=False, na=False)].reset_index(drop=True)
df_opioid
# Out:
#       rxcui                                               name   tty  \
# 0    886634  butorphanol tartrate 1 MG/ACTUAT Metered Dose ...   SCD
# 1   2201634               butorphanol Metered Dose Nasal Spray  SCDF
# 2   1740008  {2 (fentanyl 0.6 MG/ACTUAT Mucosal Spray [Subs...  BPCK
# 3   1740010  {2 (fentanyl 0.8 MG/ACTUAT Mucosal Spray [Subs...  BPCK
# 4   1740007   {2 (fentanyl 0.6 MG/ACTUAT Mucosal Spray) } Pack  GPCK
# 5   1740009   {2 (fentanyl 0.8 MG/ACTUAT Mucosal Spray) } Pack  GPCK
# 6   1115575  fentanyl 0.1 MG/ACTUAT Metered Dose Nasal Spra...   SBD
# 7   1115579  fentanyl 0.4 MG/ACTUAT Metered Dose Nasal Spra...   SBD
# 8   1237055      fentanyl 0.1 MG/ACTUAT Mucosal Spray [Subsys]   SBD
# 9   1237059      fentanyl 0.2 MG/ACTUAT Mucosal Spray [Subsys]   SBD
# 10  1237062      fentanyl 0.4 MG/ACTUAT Mucosal Spray [Subsys]   SBD
# 11  1237066      fentanyl 0.6 MG/ACTUAT Mucosal Spray [Subsys]   SBD
# 12  1237070      fentanyl 0.8 MG/ACTUAT Mucosal Spray [Subsys]   SBD
# ...

# %%
df_antid = pd.read_excel("/Users/hm/Documents/New Code/Automatic_Code_Sets/RxNorm/Appendices/Appendix8.xlsx")
keywords = ['Lotion', 'Ointment', 'Cream']
pattern = '|'.join(keywords)
df_antid = df_antid[df_antid['name'].str.contains(pattern, case=False, na=False)].reset_index(drop=True)
df_antid
# Out:
#      rxcui                                               name    tty  \
# 0  1000093  doxepin hydrochloride 50 MG/ML Topical Cream [...    SBD
# 1  1000095  doxepin hydrochloride 50 MG/ML Topical Cream [...    SBD
# 2   362333                    doxepin Topical Cream [Zonalon]   SBDF
# 3   362334                   doxepin Topical Cream [Prudoxin]   SBDF
# 4  2655083     doxepin hydrochloride Topical Cream [Prudoxin]  SBDFP
# 5  2656146      doxepin hydrochloride Topical Cream [Zonalon]  SBDFP
# 6  1000091       doxepin hydrochloride 50 MG/ML Topical Cream    SCD
# 7   377691                              doxepin Topical Cream   SCDF
#
#   ingredient
# 0    doxepin
# 1    doxepin
# 2    doxepin
# 3    doxepin
# 4    doxepin
# 5    doxepin
# 6    doxepin
# 7    doxepin

# %%
df_antid.to_excel("/Users/hm/Documents/New Code/Automatic_Code_Sets/RxNorm/Appendices/Appendix13.xlsx", index=False)
