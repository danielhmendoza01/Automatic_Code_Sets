# %%
import pandas as pd

# %%
#Global paramenters
#API URLs from RxNorm
base_url = "https://rxnav.nlm.nih.gov/REST/rxcui/"
base_url_2 = "https://rxnav.nlm.nih.gov/REST/"
#RxNorm methods
getAllRelatedInfo = "/allrelated.json"
getRelatedByType = "/related.json?tty=IN"
#dataframe
df = pd.DataFrame()

# %%
#Method to get drug with only the opioid ingredient
def query_self(name_of_drug):
    rd_df = pd.read_json(base_url+name_of_drug+getRelatedByType)
    rd_df = pd.DataFrame(rd_df.relatedGroup.conceptGroup)
    rd_df = pd.DataFrame(rd_df.conceptProperties[0])
    return rd_df

# %%
#Method to get all drugs with an opioid ingredient
def query_drug(name_of_drug):
    row = 0
    df = pd.DataFrame()
    rd_df = pd.read_json(base_url+name_of_drug+getAllRelatedInfo)
    rd_df = pd.DataFrame(rd_df.allRelatedGroup.conceptGroup)
    rd_df = rd_df.loc[rd_df["tty"] != "DF"].reset_index(drop=True)
    rd_df = rd_df.loc[rd_df["tty"] != "DFG"].reset_index(drop=True)
    while row < rd_df.shape[0]:
        if(pd.isna(rd_df.conceptProperties[row]) is True):
            row+=1
        else:
            new_df = pd.DataFrame(rd_df.conceptProperties[row])
            if df.empty:
                df = new_df
            else:
                df = pd.concat([df, new_df]).reset_index(drop=True)
            row += 1
    return df

# %% [markdown]
# ALL Opioid Ingredients

# %%
alfentanil = "480"
alphaprodine = "594"
anileridine="17933"
benzhydrocodone = "2001352"
buprenorphine = "1819"
butorphanol = "1841"
codeine = "2670"
dextromethorphan = "3289"
dextromoramide = "3290"
dezocine = "22713"
difenoxin="23024"
dihydrocodeine = "23088"
diphenoxylate = "3500"
dipipanone="23405"
ethylmorphine = "4166"
fentanyl = "4337"
heroin = "3304" 
hydrocodone = "5489"
hydromorphone = "3423"
levomethadone = "236913"
levopropoxyphene = "6377"
levorphanol = "6378"
meptazinol = "6761"
methadone = "6813"
methadyl_acetate = "6814"
morphine = "7052"
nalbuphine = "7238"
normethadone = "32009"
noscapine = "7533"
oliceridine = "2392230"
opium = "7676"
oxycodone = "7804"
oxycodone_hydrochloride = "82063"
oxymorphone = "7814"
papaveretum = "7894"
paregoric = "32926"
pentazocine = "8001"
pethidine = "6754"
phenazocine = "8119"
phenoperidine = "8143"
pholcodine = "33431"
pirinitramide = "8354"
propoxyphene = "8785"
remifentanil = "73032"
sufentanil = "56795"
tapentadol = "787390"
tetrapeptide = "1986806"
tilidine = "10597"
tramadol = "10689"

# %%
#loop array to get complete list of drugs
df_opioid = pd.DataFrame()
drugs = [alfentanil,alphaprodine,anileridine,benzhydrocodone,buprenorphine ,butorphanol ,codeine ,dextromethorphan ,dextromoramide ,dezocine,difenoxin,dihydrocodeine,diphenoxylate,dipipanone,ethylmorphine ,fentanyl ,heroin,hydrocodone ,hydromorphone ,levomethadone,levopropoxyphene,levorphanol, meptazinol ,methadone ,methadyl_acetate ,morphine ,nalbuphine ,normethadone,noscapine ,oliceridine,opium ,oxycodone ,oxycodone_hydrochloride,oxymorphone ,papaveretum ,paregoric,pentazocine ,pethidine ,phenazocine ,phenoperidine ,pholcodine,pirinitramide ,propoxyphene ,remifentanil,sufentanil,tapentadol,tetrapeptide,tilidine,tramadol]
for drug in drugs:
    self_df = query_self(drug)
    ingredient = self_df["name"].values[0]
    self_df["ingredient"] = ingredient
    merg_df = query_drug(drug)
    merg_df["ingredient"] = ingredient
    df_opioid = pd.concat([df_opioid, self_df]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
    df_opioid = pd.concat([df_opioid, merg_df]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
df_opioid
# Out:
#         rxcui                                  name synonym   tty language  \
# 0         480                            alfentanil            IN      ENG
# 1         479                               Alfenta            BN      ENG
# 2      203203              alfentanil hydrochloride           PIN      ENG
# 3      564334        alfentanil 0.5 MG/ML [Alfenta]          SBDC      ENG
# 4     1723217        alfentanil Injection [Alfenta]          SBDF      ENG
# ...       ...                                   ...     ...   ...      ...
# 3621  1157662                 tramadol Oral Product          SCDG      ENG
# 3622  1157663                         tramadol Pill          SCDG      ENG
# 3623  1295674  tramadol Disintegrating Oral Product          SCDG      ENG
# 3624  2588475     celecoxib / tramadol Oral Product          SCDG      ENG
# 3625  2588476             celecoxib / tramadol Pill          SCDG      ENG
#
#      suppress umlscui  ingredient
# ...

# %%
#Reduce to usefull columns
df_opioid = df_opioid[['rxcui', 'name',"tty", "ingredient"]]
df_opioid
# Out:
#         rxcui                                  name   tty  ingredient
# 0         480                            alfentanil    IN  alfentanil
# 1         479                               Alfenta    BN  alfentanil
# 2      203203              alfentanil hydrochloride   PIN  alfentanil
# 3      564334        alfentanil 0.5 MG/ML [Alfenta]  SBDC  alfentanil
# 4     1723217        alfentanil Injection [Alfenta]  SBDF  alfentanil
# ...       ...                                   ...   ...         ...
# 3621  1157662                 tramadol Oral Product  SCDG    tramadol
# 3622  1157663                         tramadol Pill  SCDG    tramadol
# 3623  1295674  tramadol Disintegrating Oral Product  SCDG    tramadol
# 3624  2588475     celecoxib / tramadol Oral Product  SCDG    tramadol
# 3625  2588476             celecoxib / tramadol Pill  SCDG    tramadol
#
# [3626 rows x 4 columns]

# %%
#Export
df_opioid.to_excel("New_Complete_Opioids_List.xlsx", index=False)

# %%
#take list and format it to the RXNorm api format
#This list was made by combinding the excel files
df_list = pd.read_excel("Complete_Opioids_List.xlsx")
df_list = df_list[['Code', 'Description','TTY']]
df_list.rename(columns= {'Code' : 'rxcui', 'Description': 'name'}, inplace = True)
df_list
# Out:
#         rxcui                                               name  TTY
# 0     1010600  buprenorphine 2 MG / naloxone 0.5 MG Sublingua...  SCD
# 1     1010603  buprenorphine 2 MG / naloxone 0.5 MG Sublingua...  SBD
# 2     1010604  buprenorphine 8 MG / naloxone 2 MG Sublingual ...  SCD
# 3     1010606  buprenorphine 8 MG / naloxone 2 MG Sublingual ...  SBD
# 4     1014599  acetaminophen 300 MG / oxycodone hydrochloride...  SCD
# ...       ...                                                ...  ...
# 2254   995842                                          Biotussin   BN
# 2255  2179635          tramadol hydrochloride 100 MG Oral Tablet  SCD
# 2256  2182349  chlorpheniramine maleate 0.4 MG/ML / hydrocodo...  SCD
# 2257   864826      methadone hydrochloride 5 MG/ML Oral Solution  SCD
# 2258    42347                                          Bupropion   IN
#
# [2259 rows x 3 columns]

# %%
#Identify new drugs found
same_drug_count = 0
new_drug_count = 0
drug_not_found_count = 0
same_drug = pd.DataFrame()
new_drug = pd.DataFrame()
for code in df_opioid['rxcui']:
    drug_name = df_opioid['name'].where(df_opioid['rxcui'] == code).dropna().values[0]
    if df_list.isin([int(code)]).any().any() == True:
        same_drug_count += 1
        same_drug = pd.concat([same_drug, df_opioid.loc[df_opioid['rxcui']==code]]).reset_index(drop=True)
    else:
        new_drug_count += 1
        new_drug = pd.concat([new_drug, df_opioid.loc[df_opioid['rxcui']==code]]).reset_index(drop=True)
print('Same drug count: ', same_drug_count)
print('New drug count: ', new_drug_count)
# Out:
# Same drug count:  2038
# New drug count:  1588

# %%
#export
same_drug.to_excel("Same_Opioid_Medications.xlsx", index=False)
new_drug.to_excel("New_Opioids_Added.xlsx", index=False)

# %%
absent_drugs = pd.DataFrame()
count = 0
#for every code from the combind excel list
for code in df_list['rxcui']:
    if df_opioid.isin([str(code)]).any().any() == True:
        count+=1
    else:
        absent_drugs = pd.concat([absent_drugs, df_list.loc[df_list['rxcui']==code]]).reset_index(drop=True)
print('Count: ', count)
absent_drugs
# Out:
# Count:  2038
#        rxcui                                               name  TTY
# 0    1050409  oxycodone hydrochloride 20 MG/ML Oral Solution...  SBD
# 1    1112224  chlorpheniramine maleate 0.8 MG/ML / hydrocodo...  SBD
# 2    1113998  chlorpheniramine maleate 0.4 MG/ML / codeine p...  SCD
# 3    1114002  chlorpheniramine maleate 0.4 MG/ML / codeine p...  SBD
# 4    1114003  chlorpheniramine maleate 0.4 MG/ML / codeine p...  SCD
# ..       ...                                                ...  ...
# 216    71225                          apomorphine hydrochloride  PIN
# 217    89781                            belladonna extract, USP   IN
# 218   993764                                Capital and Codeine   BN
# 219  2182349  chlorpheniramine maleate 0.4 MG/ML / hydrocodo...  SCD
# 220    42347                                          Bupropion   IN
#
# [221 rows x 3 columns]

# %%
#find the status of the not found drugs
df_status = pd.DataFrame()
index = 0
for code in absent_drugs['rxcui']:
    getRxcuiHistoryStatus = 'rxcui/{}/historystatus.json'.format(code)
    df_type = pd.read_json(base_url_2+getRxcuiHistoryStatus)
    df_type = pd.DataFrame(df_type.rxcuiStatusHistory.metaData, index=[0])
    df_type['rxcui'] = code
    df_status = pd.concat([df_status, df_type]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
df_status
# Out:
#        status  source releaseStartDate releaseEndDate isCurrent  \
# 0    Obsolete  RXNORM           012011                       NO
# 1    Obsolete  RXNORM           072011                       NO
# 2    Obsolete  RXNORM           082011                       NO
# 3    Obsolete  RXNORM           082011                       NO
# 4    Obsolete  RXNORM           082011                       NO
# ..        ...     ...              ...            ...       ...
# 216    Active  RXNORM           042005                      YES
# 217    Active  RXNORM           042005                      YES
# 218  Obsolete  RXNORM           072010                       NO
# 219  Obsolete  RXNORM           092019                       NO
# 220    Active  RXNORM           042005                      YES
#
#     activeStartDate activeEndDate remappedDate    rxcui
# 0            012011        122021               1050409
# 1            072011        052021               1112224
# ...

# %%
df_not_found = absent_drugs.merge(df_status, on='rxcui')

# %%
df_not_found = df_not_found[['rxcui', 'name','TTY', 'status']]
df_not_found
# Out:
#        rxcui                                               name  TTY    status
# 0    1050409  oxycodone hydrochloride 20 MG/ML Oral Solution...  SBD  Obsolete
# 1    1112224  chlorpheniramine maleate 0.8 MG/ML / hydrocodo...  SBD  Obsolete
# 2    1113998  chlorpheniramine maleate 0.4 MG/ML / codeine p...  SCD  Obsolete
# 3    1114002  chlorpheniramine maleate 0.4 MG/ML / codeine p...  SBD  Obsolete
# 4    1114003  chlorpheniramine maleate 0.4 MG/ML / codeine p...  SCD  Obsolete
# ..       ...                                                ...  ...       ...
# 216    71225                          apomorphine hydrochloride  PIN    Active
# 217    89781                            belladonna extract, USP   IN    Active
# 218   993764                                Capital and Codeine   BN  Obsolete
# 219  2182349  chlorpheniramine maleate 0.4 MG/ML / hydrocodo...  SCD  Obsolete
# 220    42347                                          Bupropion   IN    Active
#
# [221 rows x 4 columns]

# %%
df_active=df_not_found.loc[df_not_found['status']== 'Active'].reset_index(drop=True)
df_obsolete = df_not_found.loc[df_not_found['status']== 'Obsolete'].reset_index(drop=True)

# %%
#export
df_not_found.to_excel("Status_of_Not_found.xlsx", index=False)
df_active.to_excel("Active_Not_Found.xlsx", index=False)
df_obsolete.to_excel("Obsolete_Not_Found.xlsx", index=False)

# %% [markdown]
# True Negative

# %%
df_non = pd.read_excel("C:/Users/Daniel/Documents/opiod_list/Atomatic_Code_Sets/file_merg/Nonopioids/Nonopioid_List_Merged.xlsx")

# %%
df_non
df_non_obsolete = pd.DataFrame()

# %%
#find the status of the not found drugs
df_status = pd.DataFrame()
index = 0
for code in df_non['Code']:
    getRxcuiHistoryStatus = 'rxcui/{}/historystatus.json'.format(code)
    df_type = pd.read_json(base_url_2+getRxcuiHistoryStatus)
    df_type = pd.DataFrame(df_type.rxcuiStatusHistory.metaData, index=[0])
    df_type['rxcui'] = code
    df_status = pd.concat([df_status, df_type]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
df_status
# Out:
#       status  source releaseStartDate releaseEndDate isCurrent  \
# 0     Active  RXNORM           092010                      YES
# 1     Active  RXNORM           112010                      YES
# 2     Active  RXNORM           042005                      YES
# 3     Active  RXNORM           042005                      YES
# 4     Active  RXNORM           042005                      YES
# ...      ...     ...              ...            ...       ...
# 2923  Active  RXNORM           062010                      YES
# 2924  Active  RXNORM           062010                      YES
# 2925  Active  RXNORM           062010                      YES
# 2926  Active  RXNORM           082010                      YES
# 2927  Active  RXNORM           082010                      YES
#
#      activeStartDate activeEndDate remappedDate    rxcui
# 0             092010                             1001437
# 1             112010                             1037273
# ...

# %%
df_non
# Out:
#         rxcui                                        Description Code System  \
# 0     1001437  caffeine 50 MG / magnesium salicylate 162.5 MG...      RXNORM
# 1     1037273  acetaminophen 300 MG / phenyltoloxamine citrat...      RXNORM
# 2      103863                  aspirin 150 MG Rectal Suppository      RXNORM
# 3      103941            carbamazepine 125 MG Rectal Suppository      RXNORM
# 4      103942            carbamazepine 250 MG Rectal Suppository      RXNORM
# ...       ...                                                ...         ...
# 2923   992898   promethazine hydrochloride 1 MG/ML Oral Solution      RXNORM
# 2924   992900       promethazine hydrochloride 10 MG Oral Tablet      RXNORM
# 2925   992904       promethazine hydrochloride 20 MG Oral Tablet      RXNORM
# 2926   997658  benzalkonium chloride 1.3 MG/ML / benzocaine 5...      RXNORM
# 2927   999683  benzocaine 140 MG/ML / butamben 20 MG/ML / tet...      RXNORM
#
# ...

# %%
df_non = df_non.rename(columns={"Code": "rxcui", "Description": "name"})
non_status = df_non.merge(df_status, on='rxcui')
non_status = non_status[['rxcui', 'name','TTY', 'status']]
non_status
# Out:
#         rxcui                                               name  TTY  status
# 0     1001437  caffeine 50 MG / magnesium salicylate 162.5 MG...  SCD  Active
# 1     1037273  acetaminophen 300 MG / phenyltoloxamine citrat...  SCD  Active
# 2      103863                  aspirin 150 MG Rectal Suppository  SCD  Active
# 3      103941            carbamazepine 125 MG Rectal Suppository  SCD  Active
# 4      103942            carbamazepine 250 MG Rectal Suppository  SCD  Active
# ...       ...                                                ...  ...     ...
# 2923   992898   promethazine hydrochloride 1 MG/ML Oral Solution  SCD  Active
# 2924   992900       promethazine hydrochloride 10 MG Oral Tablet  SCD  Active
# 2925   992904       promethazine hydrochloride 20 MG Oral Tablet  SCD  Active
# 2926   997658  benzalkonium chloride 1.3 MG/ML / benzocaine 5...  SCD  Active
# 2927   999683  benzocaine 140 MG/ML / butamben 20 MG/ML / tet...  SCD  Active
#
# [2928 rows x 4 columns]

# %%
nonop_active=non_status.loc[non_status['status']== 'Active'].reset_index(drop=True)
nonop_obsolete = non_status.loc[non_status['status']== 'Obsolete'].reset_index(drop=True)

# %%
#export
non_status.to_excel("Status_of_Nonopioids.xlsx", index=False)
nonop_active.to_excel("Active_Nonopioids.xlsx", index=False)
nonop_obsolete.to_excel("Obsolete_Nonopioids.xlsx", index=False)

# %%
nonop_active_before = nonop_active
nonop_active_before
# Out:
#         rxcui                                               name  TTY  status
# 0     1001437  caffeine 50 MG / magnesium salicylate 162.5 MG...  SCD  Active
# 1     1037273  acetaminophen 300 MG / phenyltoloxamine citrat...  SCD  Active
# 2      103863                  aspirin 150 MG Rectal Suppository  SCD  Active
# 3      103941            carbamazepine 125 MG Rectal Suppository  SCD  Active
# 4      103942            carbamazepine 250 MG Rectal Suppository  SCD  Active
# ...       ...                                                ...  ...     ...
# 2765   992898   promethazine hydrochloride 1 MG/ML Oral Solution  SCD  Active
# 2766   992900       promethazine hydrochloride 10 MG Oral Tablet  SCD  Active
# 2767   992904       promethazine hydrochloride 20 MG Oral Tablet  SCD  Active
# 2768   997658  benzalkonium chloride 1.3 MG/ML / benzocaine 5...  SCD  Active
# 2769   999683  benzocaine 140 MG/ML / butamben 20 MG/ML / tet...  SCD  Active
#
# [2770 rows x 4 columns]

# %%
ingredients = ["alfentanil","alphaprodine","benzhydrocodone","buprenorphine" ,"butorphanol" ,"codeine" ,"dextromethorphan" ,"dextromoramide" ,"dezocine","dihydrocodeine","diphenoxylate" ,"ethylmorphine" ,"fentanyl" ,"heroin","hydrocodone" ,"hydromorphone" ,"levomethadone","levopropoxyphene","levorphanol", "meptazinol" ,"methadone" ,"methadyl_acetate" ,"morphine" ,"nalbuphine" ,"normethadone","noscapine" ,"oliceridine","opium" ,"oxycodone","oxymorphone" ,"papaveretum" ,"paregoric","pentazocine" ,"pethidine" ,"phenazocine" ,"phenoperidine" ,"pholcodine","pirinitramide" ,"propoxyphene" ,"remifentanil","sufentanil","tapentadol","tetrapeptide","tilidine","tramadol", "meperidine"]
for ingredient in ingredients:
    nonop_active = nonop_active[~nonop_active.name.str.contains(ingredient)]
nonop_active.reset_index(drop=True, inplace=True)
nonop_active
# Out:
#         rxcui                                               name  TTY  status
# 0     1001437  caffeine 50 MG / magnesium salicylate 162.5 MG...  SCD  Active
# 1     1037273  acetaminophen 300 MG / phenyltoloxamine citrat...  SCD  Active
# 2      103863                  aspirin 150 MG Rectal Suppository  SCD  Active
# 3      103941            carbamazepine 125 MG Rectal Suppository  SCD  Active
# 4      103942            carbamazepine 250 MG Rectal Suppository  SCD  Active
# ...       ...                                                ...  ...     ...
# 2386   992898   promethazine hydrochloride 1 MG/ML Oral Solution  SCD  Active
# 2387   992900       promethazine hydrochloride 10 MG Oral Tablet  SCD  Active
# 2388   992904       promethazine hydrochloride 20 MG Oral Tablet  SCD  Active
# 2389   997658  benzalkonium chloride 1.3 MG/ML / benzocaine 5...  SCD  Active
# 2390   999683  benzocaine 140 MG/ML / butamben 20 MG/ML / tet...  SCD  Active
#
# [2391 rows x 4 columns]

# %%
nonop_active = nonop_active.drop(columns=['status'])
nonop_active = nonop_active.rename(columns={"rxcui": "Code", "name": "Description"})
nonop_active
# Out:
#          Code                                        Description  TTY
# 0     1001437  caffeine 50 MG / magnesium salicylate 162.5 MG...  SCD
# 1     1037273  acetaminophen 300 MG / phenyltoloxamine citrat...  SCD
# 2      103863                  aspirin 150 MG Rectal Suppository  SCD
# 3      103941            carbamazepine 125 MG Rectal Suppository  SCD
# 4      103942            carbamazepine 250 MG Rectal Suppository  SCD
# ...       ...                                                ...  ...
# 2386   992898   promethazine hydrochloride 1 MG/ML Oral Solution  SCD
# 2387   992900       promethazine hydrochloride 10 MG Oral Tablet  SCD
# 2388   992904       promethazine hydrochloride 20 MG Oral Tablet  SCD
# 2389   997658  benzalkonium chloride 1.3 MG/ML / benzocaine 5...  SCD
# 2390   999683  benzocaine 140 MG/ML / butamben 20 MG/ML / tet...  SCD
#
# [2391 rows x 3 columns]

# %%
df_removed_opioids = nonop_active_before.merge(nonop_active, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']
df_removed_opioids
# Out:
#         rxcui                                               name   TTY  \
# 8     1042684  acetaminophen 33.3 MG/ML / dextromethorphan hy...   SCD
# 9     1042688  acetaminophen 325 MG / chlorpheniramine maleat...   SCD
# 10    1043400  acetaminophen 21.7 MG/ML / dextromethorphan hy...   SCD
# 15    1046384  acetaminophen 21.7 MG/ML / chlorpheniramine ma...   SCD
# 51    1086750  acetaminophen 32 MG/ML / chlorpheniramine male...   SCD
# ...       ...                                                ...   ...
# 2626   374472         benzocaine / dextromethorphan Oral Lozenge  SCDF
# 2730   858770  hydrocodone bitartrate 2.5 MG / ibuprofen 200 ...   SCD
# 2731   858778  hydrocodone bitartrate 5 MG / ibuprofen 200 MG...   SCD
# 2732   858798  hydrocodone bitartrate 7.5 MG / ibuprofen 200 ...   SCD
# 2733   859315  hydrocodone bitartrate 10 MG / ibuprofen 200 M...   SCD
#
#       status     _merge
# 8     Active  left_only
# 9     Active  left_only
# 10    Active  left_only
# ...

# %%
df_removed_opioids.reset_index(drop=True, inplace=True)
df_removed_opioids = df_removed_opioids[['rxcui', 'name','TTY', 'status']]

# %%
df_removed_opioids.to_excel("Opioids_in_Nonopioid.xlsx", index=False)
nonop_active.to_excel("Nonopioid_List.xlsx", index=False)

# %%
non_opioid = pd.DataFrame({"non_opioid_rxcui": [], "non_opioid_name": []})
count = 0
#for every code from the combind non opioid excel list
for code in df_non['Code']:
    if df_final.isin([str(code)]).any().any() == True:
        drug_name = df_non['Description'].where(df_non['Code'] == code).dropna().values[0]
        non_opioid = non_opioid.append({'non_opioid_rxcui': str(code), 'non_opioid_name': drug_name}, ignore_index = True)
        count+=1
        
print('Count: ', count)
non_opioid.head()
# Out:
# Count:  0
# Empty DataFrame
# Columns: [non_opioid_rxcui, non_opioid_name]
# Index: []

# %% [markdown]
# Get Opioid Ingredients

# %%
import tabula
tabula.convert_into("DEA_Controlled_Substances_AO.pdf", "DEA_Controlled_Substances_AO.csv", output_format="csv", pages='all')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26556/3029226719.py in <module>
# ----> 1 import tabula
#       2 tabula.convert_into("DEA_Controlled_Substances_AO.pdf", "DEA_Controlled_Substances_AO.csv", output_format="csv", pages='all')
#
# ModuleNotFoundError: No module named 'tabula'

# %%
df_dea = pd.read_csv("DEA_Controlled_Substances_AO.csv", header=None)

# %%
df_dea
# Out:
#                                                      0       1    2    3  \
# 0                  4'-Methyl acetyl fentanyl (N-(1-(4-  9819.0    I    Y
# 1    methylphenethyl)piperidin-4-yl)-N-phenylacetam...     NaN  NaN  NaN
# 2                    4-Methyl-2,5-dimethoxyamphetamine  7395.0    I    N
# 3                                                  NaN     NaN  NaN  NaN
# 4      4-methyl-alpha-ethylaminopentiophenone (4-MEAP)  7245.0    I    N
# ..                                                 ...     ...  ...  ...
# 467                                   Valeryl fentanyl  9840.0    I    Y
# 468                                        Vinbarbital  2100.0  III    N
# 469                                           Zaleplon  2781.0   IV    N
# 470                                           Zolpidem  2783.0   IV    N
# 471                                          Zopiclone  2784.0   IV    N
#
#                                                      4
# ...

# %%
df_dea.columns = ["Substance", "DEA_Number", "CSA_SCH", "NARC", "Other_Names"]

# %%
df_dea
# Out:
#                                              Substance  DEA_Number CSA_SCH  \
# 0                  4'-Methyl acetyl fentanyl (N-(1-(4-      9819.0       I
# 1    methylphenethyl)piperidin-4-yl)-N-phenylacetam...         NaN     NaN
# 2                    4-Methyl-2,5-dimethoxyamphetamine      7395.0       I
# 3                                                  NaN         NaN     NaN
# 4      4-methyl-alpha-ethylaminopentiophenone (4-MEAP)      7245.0       I
# ..                                                 ...         ...     ...
# 467                                   Valeryl fentanyl      9840.0       I
# 468                                        Vinbarbital      2100.0     III
# 469                                           Zaleplon      2781.0      IV
# 470                                           Zolpidem      2783.0      IV
# 471                                          Zopiclone      2784.0      IV
#
#     NARC                                        Other_Names
# ...

# %%
df_dea=df_dea.loc[df_dea['NARC']== 'Y'].reset_index(drop=True)

# %%
df_dea
# Out:
#                                              Substance  DEA_Number CSA_SCH  \
# 0                  4'-Methyl acetyl fentanyl (N-(1-(4-      9819.0       I
# 1                                          Acetorphine      9319.0       I
# 2    Acetyl Fentanyl  (N-(1-phenethylpiperidin-4-yl...      9821.0       I
# 3                          Acetyl-alpha-methylfentanyl      9815.0       I
# 4                                 Acetyldihydrocodeine      9051.0       I
# ..                                                 ...         ...     ...
# 138                                           Tilidine      9750.0       I
# 139          Tramadol (2-[(dimethylamino)methyl]-1-(3-      9752.0      IV
# 140                                      Trimeperidine      9646.0       I
# 141  U-47700 (3,4-dichloro-N-[2-(dimethylamino)cycl...      9547.0       I
# 142                                   Valeryl fentanyl      9840.0       I
#
#     NARC                                        Other_Names
# ...

# %%
for ingredient in ingredients:
    df_dea = df_dea[~df_dea.Substance.str.contains(ingredient, case=False)]
df_dea.reset_index(drop=True, inplace=True)

# %%
for ingredient in ingredients:
    df_dea = df_dea[~df_dea.Other_Names.str.contains(ingredient, case=False, na=False)]
df_dea.reset_index(drop=True, inplace=True)

# %%
df_dea.to_excel("Missing_Opioid_Ingredients.xlsx", index=False)

# %%
#loop array to get complete list of drugs
df_opioid = pd.DataFrame()
drugs = [fentanyl]
for drug in drugs:
    self_df = query_self(drug)
    merg_df = query_drug(drug)
    df_opioid = pd.concat([df_opioid, self_df]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
    df_opioid = pd.concat([df_opioid, merg_df]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
df_opioid
# Out:
#        rxcui                          name synonym   tty language suppress  \
# 0       4337                      fentanyl            IN      ENG        N
# 1    1053648                       Abstral            BN      ENG        N
# 2    1115547                       Lazanda            BN      ENG        N
# 3    1237051                        Subsys            BN      ENG        N
# 4     151678                     Duragesic            BN      ENG        N
# ..       ...                           ...     ...   ...      ...      ...
# 196  1237048      fentanyl Mucosal Product          SCDG      ENG        N
# 197  1294774      fentanyl Lozenge Product          SCDG      ENG        N
# 198  1294794  fentanyl Transdermal Product          SCDG      ENG        N
# 199  1294974   fentanyl Sublingual Product          SCDG      ENG        N
# 200  1295170       fentanyl Buccal Product          SCDG      ENG        N
#
#     umlscui
# 0
# 1
# 2
# 3
# 4
# ..      ...
# 196
# 197
# 198
# ...

# %%
df_opioid.to_excel("Fentanyl_List.xlsx", index=False)

# %% [markdown]
# ADD INGREDIENT COLUMN

# %%
#loop array to get complete list of drugs
df_opioid = pd.DataFrame()
drugs = [alfentanil,alphaprodine,anileridine,benzhydrocodone,buprenorphine ,butorphanol ,codeine ,dextromethorphan ,dextromoramide ,dezocine,difenoxin,dihydrocodeine,diphenoxylate,dipipanone,ethylmorphine ,fentanyl ,heroin,hydrocodone ,hydromorphone ,levomethadone,levopropoxyphene,levorphanol, meptazinol ,methadone ,methadyl_acetate ,morphine ,nalbuphine ,normethadone,noscapine ,oliceridine,opium ,oxycodone ,oxycodone_hydrochloride,oxymorphone ,papaveretum ,paregoric,pentazocine ,pethidine ,phenazocine ,phenoperidine ,pholcodine,pirinitramide ,propoxyphene ,remifentanil,sufentanil,tapentadol,tetrapeptide,tilidine,tramadol]
for drug in drugs:
    self_df = query_self(drug)
    ingredient = self_df["name"].values[0]
    self_df["ingredient"] = ingredient
    merg_df = query_drug(drug)
    merg_df["ingredient"] = ingredient
    df_opioid = pd.concat([df_opioid, self_df]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
    df_opioid = pd.concat([df_opioid, merg_df]).drop_duplicates(subset=['rxcui']).reset_index(drop=True)
df_opioid
# Out:
#         rxcui                                  name synonym   tty language  \
# 0         480                            alfentanil            IN      ENG
# 1         479                               Alfenta            BN      ENG
# 2      203203              alfentanil hydrochloride           PIN      ENG
# 3      564334        alfentanil 0.5 MG/ML [Alfenta]          SBDC      ENG
# 4     1723217        alfentanil Injection [Alfenta]          SBDF      ENG
# ...       ...                                   ...     ...   ...      ...
# 3630  1157662                 tramadol Oral Product          SCDG      ENG
# 3631  1157663                         tramadol Pill          SCDG      ENG
# 3632  1295674  tramadol Disintegrating Oral Product          SCDG      ENG
# 3633  2588475     celecoxib / tramadol Oral Product          SCDG      ENG
# 3634  2588476             celecoxib / tramadol Pill          SCDG      ENG
#
#      suppress umlscui  ingredient
# ...

# %%
df1 = pd.DataFrame({'City': ['New York', 'Chicago', 'Tokyo', 'Paris','New Delhi'],
                     'Temp': [59, 29, 73, 56,48]})

df2 = pd.DataFrame({'City': ['London', 'New York', 'Tokyo', 'New Delhi','Paris'],
                     'Temp': [55, 55, 73, 85,56]})

# %%
df = df1.merge(df2, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']

# %%
df
# Out:
#         City  Temp     _merge
# 0   New York    59  left_only
# 1    Chicago    29  left_only
# 4  New Delhi    48  left_only
